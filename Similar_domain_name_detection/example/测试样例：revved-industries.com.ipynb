# %%
from name_exist_v1 import *

# %%
run("richmondraceway.com")
# Out:
# Fuzzer耗时：1.43s
# 文件：D:\Desktop\上班\dnstwist-20230509\Similar_domain_name_detection\example\file\richmondraceway.com 1 生成的混淆域名.csv保存成功
#         fuzzer               domain     score
# 0     addition  richmondracewao.com  3.373557
# 1     addition  richmondracenay.com  3.373557
# 2     addition  richmondraceday.com  3.373557
# 3     addition  richmondracewad.com  3.373557
# 4     addition  rdchmondraceway.com  3.373557
# ...        ...                  ...       ...
# 4995  tld-swap  richmondr4cew4y.icu  3.681881
# 4996  tld-swap  richmondrace1ay.icu  3.681881
# 4997  tld-swap  richmondracexay.icu  3.681881
# 4998  tld-swap  richmondrscewsy.icu  3.681881
# 4999  tld-swap  richmondracetay.icu  3.681881
#
# [5000 rows x 3 columns]
# Domain not found!
# Domain not found!
# Domain not found!
# Domain not found!
# Domain not found!
# Domain not found!
# Domain not found!
# Domain not found!
# Domain not found!
# Domain not found!
# Domain not found!
# Domain not found!
# Domain not found!
# ...
