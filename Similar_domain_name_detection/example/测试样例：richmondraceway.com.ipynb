# %%
from name_exist_v1 import *

# %%
run("richmondraceway.com")
# Out:
# Fuzzer耗时：1.49s
# 文件：D:\Desktop\上班\dnstwist-20230509\Similar_domain_name_detection\example\file\richmondraceway.com 1 生成的混淆域名.csv保存成功
#         fuzzer               domain     score
# 0     addition  rychmondraceway.com  3.373557
# 1     addition  rochmondraceway.com  3.373557
# 2     addition  richmondracewai.com  3.373557
# 3     addition  richmondracewao.com  3.373557
# 4     addition  richmondraceyay.com  3.373557
# ...        ...                  ...       ...
# 4995  tld-swap  r4chmondraceway.org  3.681881
# 4996  tld-swap  rithmondrateway.org  3.681881
# 4997  tld-swap  richmondracezay.org  3.681881
# 4998  tld-swap  richkondraceway.org  3.681881
# 4999  tld-swap  richmondracewan.fun  3.681881
#
# [5000 rows x 3 columns]
# Domain not found!
# Domain not found!
# Domain not found!
# Domain not found!
# Domain not found!
# Domain not found!
# Domain not found!
# Domain not found!
# Domain not found!
# Domain not found!
# Domain not found!
# Domain not found!
# Domain not found!
# ...
