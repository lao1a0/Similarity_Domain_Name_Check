# %% [markdown]
# # 代码

# %%
from name_exit import *

# %% [markdown]
# # 超参数

# %%
args = {
    'domain': 'ktea.com',
    'option_lsh': 'ssdeep',  # 使用LSH算法评估网页相似度: ssdeep
    'threads': 30,
    'dns_type': 1,
    'fuzzer_num': np.inf,  # 0-np.inf，inf代表输出所有的生成结果
    'threshold_value': 0.15,
    'tld_all': True,
    'fuzzers': [
#         'bitsquatting', 'vowel-swap', 'cyrillic', 'homoglyph', 'repetition',
        'addition',
        'hyphenation',
        'insertion', 'omission', 'replacement',
        'subdomain', 'transposition'
    ],
    'useragent': USER_AGENT_STRING,
    'request_timeout_http': 3
}

# %% [markdown]
# # 主程序

# %%
import time

t1=time.time()
url = UrlParser(args['domain'])
fuzz = fuzzer_plus.Fuzzer(domain=url.domain, tld_all=args['tld_all'], threshold_value=args['threshold_value'],
                          top=args['fuzzer_num'])
fuzz.generate(args['fuzzers'])
domains = list(fuzz.domains)
len_fuzz=len(domains)

# %%
pd.DataFrame(domains)
# Out:
#        fuzzer     domain     score
# 0    addition  kteae.biz  2.947703
# 1    addition  aktea.biz  2.947703
# 2    addition  ketea.biz  2.947703
# 3    addition  ketea.biz  2.947703
# 4    addition  ktkea.biz  2.947703
# ..        ...        ...       ...
# 335  addition   otea.fun  3.000000
# 336  addition   koea.biz  3.000000
# 337  addition   k7ea.biz  3.000000
# 338  addition   kte6.fun  3.000000
# 339  addition   ktem.fun  3.000000
#
# [340 rows x 3 columns]

# %%
_ = min(args['fuzzer_num'], len(domains))
domains = domains[:_].copy()
t2=time.time()
print("Fuzzer耗时：{:.2f}s".format(t2-t1))
# Out:
# Fuzzer耗时：0.51s

# %%
# t3=time.time()
# domains = search_status_code(domains, args['request_timeout_http'], args['threads'])
save_domains(domains, "{}生成的混淆域名".format(url.domain))
# t4=time.time()
# print("request发包过滤耗时：{:.2f}s".format(t4-t3))
# Out:
# 文件：D:\Desktop\上班\dnstwist-20230509\Similar_domain_name_detection\ktea.com生成的混淆域名.csv保存成功

# %%
fuzz._make_fig(url.domain)

# %%
# domains = search_dns(domains, _type=args['dns_type'], tnum=args['threads'])
# save_domains(domains, "DNS过滤后的混淆域名")

# %%
t5=time.time()
domains = LSH_alg(args['domain'], domains, args['request_timeout_http'], args['useragent'], args['option_lsh'])
save_domains(domains, "{}LSH过滤后的混淆域名".format(url.domain))
t6=time.time()
len_lsh=len(domains)
# Out:
# 将要进行LSH检测的域名：
#
#        fuzzer     domain     score
# 0    addition  kteae.biz  2.947703
# 1    addition  aktea.biz  2.947703
# 2    addition  ketea.biz  2.947703
# 3    addition  ketea.biz  2.947703
# 4    addition  ktkea.biz  2.947703
# ..        ...        ...       ...
# 335  addition   otea.fun  3.000000
# 336  addition   koea.biz  3.000000
# 337  addition   k7ea.biz  3.000000
# 338  addition   kte6.fun  3.000000
# 339  addition   ktem.fun  3.000000
#
# [340 rows x 3 columns]
# >utea.biz查询出错：HTTP Error 404: Not Found
# >ktex.biz的LSH得分：0 http://ktex.biz
# >katea.biz的LSH得分：0 http://katea.biz>kmea.biz查询出错：<urlopen error [Errno 11002] getaddrinfo failed>
#
# >krea.biz的LSH得分：0 http://krea.biz
# >take.biz的LSH得分：0 http://take.biz
# >katea.biz的LSH得分：0 http://katea.biz
# >ktec.biz查询出错：<urlopen error timed out>
# >ltea.biz查询出错：HTTP Error 403: Forbidden
# >ktex.biz的LSH得分：0 http://ktex.biz
# >utea.biz查询出错：HTTP Error 404: Not Found
# >kate.biz查询出错：HTTP Error 403: Forbidden
# >kten.biz的LSH得分：0 https://www.kten.biz/
# >akte.biz的LSH得分：0 https://www.kienhuis.eu/
# >take.biz的LSH得分：0 http://take.biz
# >ekat.biz的LSH得分：0 https://www.ekat.com/
# >ekat.biz的LSH得分：0 https://www.ekat.com/
# >ktpa.biz的LSH得分：0 http://ktpa.biz/adm/account/loginV.php
# >atek.biz的LSH得分：0 http://atek.biz
# >atek.biz的LSH得分：0 http://atek.biz
# >kmea.biz查询出错：<urlopen error [Errno 11002] getaddrinfo failed>
# >ktua.biz的LSH得分：0 http://ktua.biz
# >ktua.biz的LSH得分：0 http://ktua.biz
# >kten.biz查询出错：timed out
# >ktec.biz查询出错：<urlopen error timed out>
# >krea.biz的LSH得分：0 http://krea.biz
# >ctea.biz查询出错：<urlopen error timed out>
# >ctea.biz查询出错：<urlopen error timed out>
# >ltea.biz查询出错：HTTP Error 403: Forbidden
# >ktpa.biz的LSH得分：0 http://ktpa.biz/adm/account/loginV.php
# >akte.biz的LSH得分：0 https://www.kienhuis.eu/
# >ktea.biz查询出错：<urlopen error [WinError 10061] 由于目标计算机积极拒绝，无法连接。>
# >ktea.biz查询出错：<urlopen error [WinError 10061] 由于目标计算机积极拒绝，无法连接。>
# >kate.biz查询出错：HTTP Error 403: Forbidden
# 文件：D:\Desktop\上班\dnstwist-20230509\Similar_domain_name_detection\ktea.comLSH过滤后的混淆域名.csv保存成功

# %%
pd.DataFrame(domains)
# Out:
#       fuzzer     domain     score  \
# 0   addition   utea.biz  3.000000
# 1   addition   ktex.biz  3.000000
# 2   addition   kmea.biz  3.000000
# 3   addition  katea.biz  2.947703
# 4   addition   krea.biz  3.000000
# 5   addition   take.biz  3.000000
# 6   addition  katea.biz  2.947703
# 7   addition   ktec.biz  3.000000
# 8   addition   ltea.biz  3.000000
# 9   addition   ktex.biz  3.000000
# 10  addition   utea.biz  3.000000
# 11  addition   kate.biz  3.000000
# 12  addition   kten.biz  3.000000
# 13  addition   akte.biz  3.000000
# 14  addition   take.biz  3.000000
# 15  addition   ekat.biz  3.000000
# 16  addition   ekat.biz  3.000000
# 17  addition   ktpa.biz  3.000000
# 18  addition   atek.biz  3.000000
# 19  addition   atek.biz  3.000000
# 20  addition   kmea.biz  3.000000
# 21  addition   ktua.biz  3.000000
# 22  addition   ktua.biz  3.000000
# 23  addition   kten.biz  3.000000
# 24  addition   ktec.biz  3.000000
# 25  addition   krea.biz  3.000000
# 26  addition   ctea.biz  3.000000
# 27  addition   ctea.biz  3.000000
# 28  addition   ltea.biz  3.000000
# 29  addition   ktpa.biz  3.000000
# 30  addition   akte.biz  3.000000
# 31  addition   ktea.biz  3.000000
# 32  addition   ktea.biz  3.000000
# 33  addition   kate.biz  3.000000
#
#                                             LSH_score
# 0                           HTTP Error 404: Not Found
# 1                                                   0
# 2    <urlopen error [Errno 11002] getaddrinfo failed>
# 3                                                   0
# 4                                                   0
# 5                                                   0
# 6                                                   0
# 7                           <urlopen error timed out>
# 8                           HTTP Error 403: Forbidden
# 9                                                   0
# 10                          HTTP Error 404: Not Found
# 11                          HTTP Error 403: Forbidden
# 12                                          timed out
# 13                                                  0
# 14                                                  0
# 15                                                  0
# 16                                                  0
# 17                                                  0
# 18                                                  0
# 19                                                  0
# 20   <urlopen error [Errno 11002] getaddrinfo failed>
# 21                                                  0
# 22                                                  0
# 23                                          timed out
# 24                          <urlopen error timed out>
# 25                                                  0
# 26                          <urlopen error timed out>
# 27                          <urlopen error timed out>
# 28                          HTTP Error 403: Forbidden
# 29                                                  0
# 30                                                  0
# 31  <urlopen error [WinError 10061] 由于目标计算机积极拒绝，无法...
# 32  <urlopen error [WinError 10061] 由于目标计算机积极拒绝，无法...
# 33                          HTTP Error 403: Forbidden

# %%
print("LSH过滤过滤耗时：{:.2f}s".format(t6-t5))
# Out:
# LSH过滤过滤耗时：201.73s

# %%
sum_time=t6-t1
print("共计耗时：{:.2f}s".format(sum_time))
# Out:
# 共计耗时：202.50s

# %% [markdown]
# # 结论

# %%
banner='''
1. 对域名{}进行探索，fuzzer生成{}条域名。
2. 取前{}条进行ssdeep过滤，得到{}条互联网中存活的域名，得到的结果表如下，未发现有相似的网页
3. 共计耗时：{:.2f}s，超参数设置如下：\n\n{}
'''.format(url.domain,len_fuzz,args['fuzzer_num'],len_lsh,sum_time,args)
print(banner)
# Out:
# 1. 对域名ktea.com进行探索，fuzzer生成340条域名。
# 2. 取前inf条进行ssdeep过滤，得到34条互联网中存活的域名，得到的结果表如下，未发现有相似的网页
# 3. 共计耗时：202.50s，超参数设置如下：
#
# {'domain': 'ktea.com', 'option_lsh': 'ssdeep', 'threads': 30, 'dns_type': 1, 'fuzzer_num': inf, 'threshold_value': 0.15, 'tld_all': True, 'fuzzers': ['addition', 'hyphenation', 'insertion', 'omission', 'replacement', 'subdomain', 'transposition'], 'useragent': 'Mozilla/5.0 (win32 64-bit) dnstwist/20230526', 'request_timeout_http': 3}

# %%
pd.DataFrame(domains)
# Out:
#       fuzzer     domain     score  \
# 0   addition   utea.biz  3.000000
# 1   addition   ktex.biz  3.000000
# 2   addition   kmea.biz  3.000000
# 3   addition  katea.biz  2.947703
# 4   addition   krea.biz  3.000000
# 5   addition   take.biz  3.000000
# 6   addition  katea.biz  2.947703
# 7   addition   ktec.biz  3.000000
# 8   addition   ltea.biz  3.000000
# 9   addition   ktex.biz  3.000000
# 10  addition   utea.biz  3.000000
# 11  addition   kate.biz  3.000000
# 12  addition   kten.biz  3.000000
# 13  addition   akte.biz  3.000000
# 14  addition   take.biz  3.000000
# 15  addition   ekat.biz  3.000000
# 16  addition   ekat.biz  3.000000
# 17  addition   ktpa.biz  3.000000
# 18  addition   atek.biz  3.000000
# 19  addition   atek.biz  3.000000
# 20  addition   kmea.biz  3.000000
# 21  addition   ktua.biz  3.000000
# 22  addition   ktua.biz  3.000000
# 23  addition   kten.biz  3.000000
# 24  addition   ktec.biz  3.000000
# 25  addition   krea.biz  3.000000
# 26  addition   ctea.biz  3.000000
# 27  addition   ctea.biz  3.000000
# 28  addition   ltea.biz  3.000000
# 29  addition   ktpa.biz  3.000000
# 30  addition   akte.biz  3.000000
# 31  addition   ktea.biz  3.000000
# 32  addition   ktea.biz  3.000000
# 33  addition   kate.biz  3.000000
#
#                                             LSH_score
# 0                           HTTP Error 404: Not Found
# 1                                                   0
# 2    <urlopen error [Errno 11002] getaddrinfo failed>
# 3                                                   0
# 4                                                   0
# 5                                                   0
# 6                                                   0
# 7                           <urlopen error timed out>
# 8                           HTTP Error 403: Forbidden
# 9                                                   0
# 10                          HTTP Error 404: Not Found
# 11                          HTTP Error 403: Forbidden
# 12                                          timed out
# 13                                                  0
# 14                                                  0
# 15                                                  0
# 16                                                  0
# 17                                                  0
# 18                                                  0
# 19                                                  0
# 20   <urlopen error [Errno 11002] getaddrinfo failed>
# 21                                                  0
# 22                                                  0
# 23                                          timed out
# 24                          <urlopen error timed out>
# 25                                                  0
# 26                          <urlopen error timed out>
# 27                          <urlopen error timed out>
# 28                          HTTP Error 403: Forbidden
# 29                                                  0
# 30                                                  0
# 31  <urlopen error [WinError 10061] 由于目标计算机积极拒绝，无法...
# 32  <urlopen error [WinError 10061] 由于目标计算机积极拒绝，无法...
# 33                          HTTP Error 403: Forbidden
