# %%
# !/usr/bin/env python3
# -*- coding: utf-8 -*-

__author__ = 'laolao'
__version__ = '20230526'
__email__ = 'xxx@xxx.com'

from setuptools.package_index import user_agent
import re
import sys
import socket

import fuzzer_plus
from dependent_function import REQUEST_TIMEOUT_HTTP, _debug, UrlOpener, UrlParser, my_reshape, save_domains

socket.setdefaulttimeout(12.0)
import numpy as np
import pandas as pd
import threading
import os
import queue

try:
    import tlsh

    MODULE_TLSH = True
except ImportError as e:
    _debug(e)
    MODULE_TLSH = False

try:
    import ssdeep

    MODULE_SSDEEP = True
except ImportError as e:
    _debug(e)
    try:
        import ppdeep as ssdeep

        MODULE_SSDEEP = True
    except ImportError as e:
        _debug(e)
        MODULE_SSDEEP = False

try:
    import idna
except ImportError as e:
    _debug(e)


    class idna:
        @staticmethod
        def decode(domain):
            return domain.encode().decode('idna')

        @staticmethod
        def encode(domain):
            return domain.encode('idna')

VALID_FQDN_REGEX = re.compile(r'(?=^.{4,253}$)(^((?!-)[a-z0-9-]{1,63}(?<!-)\.)+[a-z0-9-]{2,63}$)',
                              re.IGNORECASE)  # 有效的FQDN正则表达式
USER_AGENT_STRING = 'Mozilla/5.0 ({} {}-bit) dnstwist/{}'.format(sys.platform, sys.maxsize.bit_length() + 1,
                                                                 __version__)
THREAD_COUNT_DEFAULT = min(32, os.cpu_count() + 4)


def search_dns(domains, _type=1, thread_num=4):
    ''':cvar
    _type：控制查询级别，默认查询A记录
        1：A
        2: NS
        3: MX
        4+: AAAA
    A记录，将主机名转换为IP地址；[默认]
    MX记录，邮件交换记录，定义邮件服务器的域名；
    NS记录，标记区域的域名服务器及授权子域；
    AAAA记录，ipv6
    '''
    print('Fuzzer后生成的域名：\n')
    print(pd.DataFrame(domains))
    domains = list(domains)
    from dns.resolver import Resolver
    import dns.rdatatype
    resolv = Resolver()
    if hasattr(resolv, 'resolve'):
        resolve = resolv.resolve
    else:
        resolve = resolv.query

    def __answer_to_list(_, _type):
        ''':cvar 输入域名，输出对应的dns记录'''
        try:
            if _type == 2:
                _re = resolve(_, rdtype=dns.rdatatype.NS)
            elif _type == 3:
                _re = resolve(_, rdtype=dns.rdatatype.MX)
            elif _type >= 4:
                _re = resolve(_, rdtype=dns.rdatatype.AAAA)
            else:
                _re = resolve(_, rdtype=dns.rdatatype.A)
            _ = []
            for i in _re:
                for j in str(i).split('\n'):
                    _.append(j.split(' ')[-1])
            return _
        except:
            print('>{} 解析结果：Check no record'.format(_))
            return []

    def __job_search_dns(domains, q):
        for _ in domains:
            ip_list = __answer_to_list(_['domain'], _type)
            if len(ip_list):  # 没有记录的直接过滤掉
                _['dns_record'] = ','.join(list(set(ip_list)))
                print('>{} 解析结果：{}'.format(_['domain'], _['dns_record']))
                q.put(_)

    q = queue.Queue()
    threads = []  # 线程列表
    data = my_reshape(domains, thread_num)
    for i in range(thread_num):
        t = threading.Thread(target=__job_search_dns, args=(data[i], q))
        t.start()
        threads.append(t)
    for thread in threads:
        thread.join()
    new_domains = []
    for _ in range(q.qsize()):
        new_domains.append(q.get())
    print("\nDNS查询过滤域名个数：{}->{}".format(len(domains), len(new_domains)))
    print(pd.DataFrame(new_domains))
    return new_domains


def __job_LSH_alg(domains, lsh_init, REQUEST_TIMEOUT_HTTP, option_lsh, q):
    for _ in domains:
        try:
            r = UrlOpener(UrlParser(_['domain']).full_uri(),
                          timeout=REQUEST_TIMEOUT_HTTP,
                          headers={'user-agent': user_agent},
                          verify=False)
        except Exception as e:
            print(">{}查询出错：{}".format(_['domain'], e))
            _['LSH_score'] = -1
            q.put(_)
        else:
            _['LSH_score'] = -1  # 默认值 -1
            if option_lsh == 'ssdeep':
                lsh_curr = ssdeep.hash(r.normalized_content)
                if lsh_curr not in (None, '3::'):
                    _['LSH_score'] = ssdeep.compare(lsh_init, lsh_curr)
            elif option_lsh == 'tlsh':
                lsh_curr = tlsh.hash(r.normalized_content)
                if lsh_curr not in (None, '', 'TNULL'):
                    _['LSH_score'] = int(100 - (min(tlsh.diff(lsh_init, lsh_curr), 300) / 3))
            print('>{}的LSH得分：{}'.format(_['domain'], _['LSH_score']))
            q.put(_)


def LSH_alg(url_raw, domains, REQUEST_TIMEOUT_HTTP, user_agent, option_lsh='ssdeep', thread_num=4):
    print('\n将要进行LSH检测的域名：\n')
    print(pd.DataFrame(domains))
    r = UrlOpener(UrlParser(url_raw).full_uri(),
                  timeout=REQUEST_TIMEOUT_HTTP,
                  headers={'user-agent': user_agent},
                  verify=False)
    if option_lsh == 'ssdeep':
        lsh_init = ssdeep.hash(r.normalized_content)
    else:
        lsh_init = tlsh.hash(r.normalized_content)

    q = queue.Queue()
    threads = []  # 线程列表
    data = my_reshape(domains, thread_num)

    for i in range(thread_num):
        t = threading.Thread(target=__job_LSH_alg, args=(data[i], lsh_init, REQUEST_TIMEOUT_HTTP, option_lsh, q))
        t.start()
        threads.append(t)
    for thread in threads:
        thread.join()
    new_domains = []
    for _ in range(q.qsize()):
        new_domains.append(q.get())
    return new_domains

# %%
args = {
    'all': False,
    'format': 'cli',  # csv/json/cli
    'domain': 'https://www.bjtu.edu.cn',
    'option_lsh': 'ssdeep',  # 使用LSH算法评估网页相似度: ssdeep, tlsh(默认:ssdeep)
    'phash': False,
    'screenshots': False,  # argument --screenshots requires --phash
    'threads': 20,
    'dns_type': 1,
    'fuzzer_num': 1000,  # 0-inf，inf代表输出所有的生成结果
    'threshold_value': 0.15,
    'tld_all': True,
    'fuzzers': [
        'addition', 'bitsquatting',
#         'cyrillic', 'homoglyph', # 这两个查不到什么有用的
        'hyphenation',
        'insertion', 'omission', 'repetition', 'replacement',
        'subdomain', 'transposition', 'vowel-swap', 'dictionary'
    ],
    'useragent': USER_AGENT_STRING,
    'request_timeout_http': REQUEST_TIMEOUT_HTTP
}

# %%
url = UrlParser(args['domain'])
fuzz = fuzzer_plus.Fuzzer(url.domain, tld_all=args['tld_all'], threshold_value=args['threshold_value'], top=args['fuzzer_num'])
fuzz.generate(args['fuzzers'])
domains = fuzz.domains

# %%
pd.DataFrame(domains)
# Out:
#        fuzzer            domain         score
# 0    addition   www.bjru.edu.cn  0.000000e+00
# 1    addition  www.bjtuu.edu.cn  3.111367e-02
# 2    addition   www.bjt7.edu.cn  1.333333e-01
# 3    addition   www.bptu.edu.cn  0.000000e+00
# 4    addition  www.bjtju.edu.cn  1.606680e-02
# ..        ...               ...           ...
# 162  addition   www.bytu.edu.cn  4.440892e-16
# 163  addition   www.jutb.edu.cn  0.000000e+00
# 164  addition   www.xjtu.edu.cn  4.440892e-16
# 165  addition   www.bjtq.edu.cn  1.333333e-01
# 166  addition  www.bjtbu.edu.cn  1.606680e-02
#
# [167 rows x 3 columns]

# %%
save_domains(domains, "{}生成的混淆域名".format(url.domain))
# Out:
# 文件：D:\Desktop\上班\dnstwist-20230509\Similar_domain_name_detection\www.bjtu.edu.cn生成的混淆域名.csv保存成功

# %%
fuzz._make_fig(url.domain)

# %%
domains = search_dns(domains, _type=args['dns_type'], thread_num=args['threads'])
# Out:
# Fuzzer后生成的域名：
#
#        fuzzer            domain         score
# 0    addition   www.bjru.edu.cn  0.000000e+00
# 1    addition  www.bjtuu.edu.cn  3.111367e-02
# 2    addition   www.bjt7.edu.cn  1.333333e-01
# 3    addition   www.bptu.edu.cn  0.000000e+00
# 4    addition  www.bjtju.edu.cn  1.606680e-02
# ..        ...               ...           ...
# 162  addition   www.bytu.edu.cn  4.440892e-16
# 163  addition   www.jutb.edu.cn  0.000000e+00
# 164  addition   www.xjtu.edu.cn  4.440892e-16
# 165  addition   www.bjtq.edu.cn  1.333333e-01
# 166  addition  www.bjtbu.edu.cn  1.606680e-02
#
# [167 rows x 3 columns]
# >www.bjut.edu.cn 解析结果：27.221.108.52,116.211.138.205
# >www.bjtd.edu.cn 解析结果：Check no record
# >www.bjtx.edu.cn 解析结果：Check no record
# >www.8jtu.edu.cn 解析结果：Check no record
# >www.bjt8.edu.cn 解析结果：Check no record
# >www.bjru.edu.cn 解析结果：Check no record
# >www.ujtb.edu.cn 解析结果：Check no record
# >www.4jtu.edu.cn 解析结果：Check no record
# >www.bjtf.edu.cn 解析结果：Check no record
# >www.sjtu.edu.cn 解析结果：202.120.2.119
# >www.bjt4.edu.cn 解析结果：Check no record
# >www.bjmu.edu.cn 解析结果：202.112.190.162
# >www.bjutu.edu.cn 解析结果：Check no record
# >www.1jtu.edu.cn 解析结果：Check no record
# >www.bjiu.edu.cn 解析结果：Check no record
# >www.ejtu.edu.cn 解析结果：Check no record
# >www.betu.edu.cn 解析结果：Check no record
# >www.bjt6.edu.cn 解析结果：Check no record
# >www.bitu.edu.cn 解析结果：Check no record
# >www.bjtub.edu.cn 解析结果：Check no record
# >www.bjt5.edu.cn 解析结果：Check no record
# >www.kjtu.edu.cn 解析结果：Check no record
# >www.bjzu.edu.cn 解析结果：Check no record>www.b-tu.edu.cn 解析结果：Check no record
#
# >www.bjtuu.edu.cn 解析结果：Check no record
# >www.btjtu.edu.cn 解析结果：Check no record
# >www.batu.edu.cn 解析结果：Check no record
# >www.djtu.edu.cn 解析结果：202.199.128.144
# >www.bjtu.edu.cn 解析结果：202.112.154.197
# >www.ujbt.edu.cn 解析结果：Check no record
# >www.bjeu.edu.cn 解析结果：Check no record
# >www.bjyu.edu.cn 解析结果：Check no record
# >www.butj.edu.cn 解析结果：Check no record
# >www.btju.edu.cn 解析结果：Check no record
# >www.bftu.edu.cn 解析结果：Check no record
# >www.bjku.edu.cn 解析结果：Check no record
# >www.bjt0.edu.cn 解析结果：Check no record
# >www.tjub.edu.cn 解析结果：Check no record>www.6jtu.edu.cn 解析结果：Check no record
#
# >www.bjt7.edu.cn 解析结果：Check no record
# >www.b9tu.edu.cn 解析结果：Check no record
# >www.bntu.edu.cn 解析结果：Check no record
# >www.bjqu.edu.cn 解析结果：Check no record
# >www.bj2u.edu.cn 解析结果：Check no record
# >www.bltu.edu.cn 解析结果：Check no record
# >www.bjhu.edu.cn 解析结果：Check no record
# >www.bjpu.edu.cn 解析结果：Check no record
# >www.bhtu.edu.cn 解析结果：Check no record
# >www.bjt2.edu.cn 解析结果：Check no record
# >www.bj-u.edu.cn 解析结果：Check no record
# >www.bjto.edu.cn 解析结果：Check no record
# >www.utbj.edu.cn 解析结果：Check no record
# >www.bjtn.edu.cn 解析结果：Check no record
# >www.jubt.edu.cn 解析结果：Check no record
# >www.tbuj.edu.cn 解析结果：Check no record
# >www.btuj.edu.cn 解析结果：Check no record
# >www.bujtu.edu.cn 解析结果：Check no record
# >www.bptu.edu.cn 解析结果：Check no record
# >www.bj6u.edu.cn 解析结果：Check no record
# >www.tbjtu.edu.cn 解析结果：Check no record
# >www.b0tu.edu.cn 解析结果：Check no record
# >www.jbut.edu.cn 解析结果：Check no record
# >www.bjou.edu.cn 解析结果：111.198.125.95
# >www.bjcu.edu.cn 解析结果：Check no record
# >www.bgtu.edu.cn 解析结果：Check no record
# >www.ubjtu.edu.cn 解析结果：Check no record
# >www.b4tu.edu.cn 解析结果：Check no record
# >www.ubjt.edu.cn 解析结果：Check no record
# >www.bj1u.edu.cn 解析结果：Check no record
# >www.bjtk.edu.cn 解析结果：Check no record
# >www.utjb.edu.cn 解析结果：Check no record
# >www.bjty.edu.cn 解析结果：Check no record
# >www.bjau.edu.cn 解析结果：Check no record
# >www.bjtju.edu.cn 解析结果：Check no record
# >www.bjtm.edu.cn 解析结果：Check no record
# >www.b6tu.edu.cn 解析结果：Check no record
# >www.bjtv.edu.cn 解析结果：Check no record
# >www.bjtz.edu.cn 解析结果：Check no record
# >www.zjtu.edu.cn 解析结果：61.163.28.158
# >www.njtu.edu.cn 解析结果：202.112.154.197
# >www.bjti.edu.cn 解析结果：Check no record
# >www.3jtu.edu.cn 解析结果：Check no record
# >www.bjtg.edu.cn 解析结果：Check no record
# >www.b8tu.edu.cn 解析结果：Check no record
# >www.bj0u.edu.cn 解析结果：Check no record
# >www.bjts.edu.cn 解析结果：Check no record
# >www.bjlu.edu.cn 解析结果：Check no record
# >www.tbju.edu.cn 解析结果：Check no record
# >www.jtub.edu.cn 解析结果：Check no record
# >www.bj5u.edu.cn 解析结果：Check no record
# >www.bjfu.edu.cn 解析结果：202.204.112.10
# >www.bjtl.edu.cn 解析结果：Check no record
# >www.bktu.edu.cn 解析结果：Check no record
# >www.bjtuj.edu.cn 解析结果：Check no record
# >www.bjtr.edu.cn 解析结果：Check no record
# >www.bjvu.edu.cn 解析结果：Check no record
# >www.ajtu.edu.cn 解析结果：Check no record
# >www.bj8u.edu.cn 解析结果：Check no record
# >www.bmtu.edu.cn 解析结果：Check no record
# >www.bjbtu.edu.cn 解析结果：Check no record
# >www.bvtu.edu.cn 解析结果：Check no record
# >www.bjt1.edu.cn 解析结果：Check no record
# >www.ljtu.edu.cn 解析结果：Check no record
# >www.botu.edu.cn 解析结果：Check no record
# >www.bctu.edu.cn 解析结果：Check no record
# >www.b1tu.edu.cn 解析结果：Check no record
# >www.bxtu.edu.cn 解析结果：Check no record
# >www.ubtj.edu.cn 解析结果：Check no record
# >www.b2tu.edu.cn 解析结果：Check no record
# >www.b7tu.edu.cn 解析结果：Check no record
# >www.tubj.edu.cn 解析结果：Check no record
# >www.bjtw.edu.cn 解析结果：Check no record
# >www.brtu.edu.cn 解析结果：Check no record
# >www.mjtu.edu.cn 解析结果：Check no record
# >www.hjtu.edu.cn 解析结果：Check no record
# >www.cjtu.edu.cn 解析结果：Check no record
# >www.bjtc.edu.cn 解析结果：Check no record
# >www.gjtu.edu.cn 解析结果：Check no record
# >www.bjt3.edu.cn 解析结果：Check no record
# >www.bjnu.edu.cn 解析结果：Check no record
# >www.bj9u.edu.cn 解析结果：Check no record
# >www.bj7u.edu.cn 解析结果：Check no record
# >www.bjtut.edu.cn 解析结果：Check no record
# >www.tujb.edu.cn 解析结果：Check no record
# >www.jbjtu.edu.cn 解析结果：Check no record
# >www.pjtu.edu.cn 解析结果：Check no record
# >www.yjtu.edu.cn 解析结果：Check no record
# >www.jtbu.edu.cn 解析结果：Check no record
# >www.bjxu.edu.cn 解析结果：Check no record
# >www.9jtu.edu.cn 解析结果：Check no record
# >www.7jtu.edu.cn 解析结果：Check no record
# >www.bjth.edu.cn 解析结果：Check no record
# >www.bjdu.edu.cn 解析结果：Check no record
# >www.bj3u.edu.cn 解析结果：Check no record
# >www.bjgu.edu.cn 解析结果：Check no record
# >www.bjjtu.edu.cn 解析结果：Check no record
# >www.ojtu.edu.cn 解析结果：Check no record
# >www.jbtu.edu.cn 解析结果：Check no record
# >www.qjtu.edu.cn 解析结果：Check no record
# >www.rjtu.edu.cn 解析结果：Check no record
# >www.bujt.edu.cn 解析结果：Check no record
# >www.fjtu.edu.cn 解析结果：Check no record
# >www.bjta.edu.cn 解析结果：Check no record
# >www.bjttu.edu.cn 解析结果：Check no record
# >www.bj4u.edu.cn 解析结果：Check no record
# >www.ijtu.edu.cn 解析结果：Check no record
# >www.b5tu.edu.cn 解析结果：Check no record
# >www.b3tu.edu.cn 解析结果：Check no record
# >www.xjtu.edu.cn 解析结果：202.117.1.13
# >www.bjte.edu.cn 解析结果：Check no record
# >www.bdtu.edu.cn 解析结果：Check no record
# >www.vjtu.edu.cn 解析结果：Check no record
# >www.2jtu.edu.cn 解析结果：Check no record
# >www.bytu.edu.cn 解析结果：Check no record
# >www.0jtu.edu.cn 解析结果：Check no record
# >www.bjsu.edu.cn 解析结果：Check no record
# >www.bjtp.edu.cn 解析结果：Check no record
# >www.bqtu.edu.cn 解析结果：Check no record
# >www.bjtbu.edu.cn 解析结果：Check no record
# >www.bstu.edu.cn 解析结果：Check no record
# >www.tjbu.edu.cn 解析结果：Check no record
# >www.5jtu.edu.cn 解析结果：Check no record
# >www.bbjtu.edu.cn 解析结果：Check no record
# >www.bjtq.edu.cn 解析结果：Check no record
# >www.bjt9.edu.cn 解析结果：Check no record
# >www.bztu.edu.cn 解析结果：Check no record
# >www.jutb.edu.cn 解析结果：Check no record
#
# DNS查询过滤域名个数：167->10
#      fuzzer           domain         score                     dns_record
# 0  addition  www.bjut.edu.cn  0.000000e+00  27.221.108.52,116.211.138.205
# 1  addition  www.sjtu.edu.cn  4.440892e-16                  202.120.2.119
# 2  addition  www.bjmu.edu.cn  0.000000e+00                202.112.190.162
# 3  addition  www.djtu.edu.cn  1.333333e-01                202.199.128.144
# 4  addition  www.bjtu.edu.cn  0.000000e+00                202.112.154.197
# 5  addition  www.bjou.edu.cn  0.000000e+00                 111.198.125.95
# 6  addition  www.zjtu.edu.cn  4.440892e-16                  61.163.28.158
# 7  addition  www.njtu.edu.cn  1.333333e-01                202.112.154.197
# 8  addition  www.bjfu.edu.cn  0.000000e+00                 202.204.112.10
# 9  addition  www.xjtu.edu.cn  4.440892e-16                   202.117.1.13

# %%
pd.DataFrame(domains)
# Out:
#      fuzzer           domain         score                     dns_record
# 0  addition  www.bjut.edu.cn  0.000000e+00  27.221.108.52,116.211.138.205
# 1  addition  www.sjtu.edu.cn  4.440892e-16                  202.120.2.119
# 2  addition  www.bjmu.edu.cn  0.000000e+00                202.112.190.162
# 3  addition  www.djtu.edu.cn  1.333333e-01                202.199.128.144
# 4  addition  www.bjtu.edu.cn  0.000000e+00                202.112.154.197
# 5  addition  www.bjou.edu.cn  0.000000e+00                 111.198.125.95
# 6  addition  www.zjtu.edu.cn  4.440892e-16                  61.163.28.158
# 7  addition  www.njtu.edu.cn  1.333333e-01                202.112.154.197
# 8  addition  www.bjfu.edu.cn  0.000000e+00                 202.204.112.10
# 9  addition  www.xjtu.edu.cn  4.440892e-16                   202.117.1.13

# %%
save_domains(domains, "{}DNS过滤后的混淆域名".format(url.domain))
# Out:
# 文件：D:\Desktop\上班\dnstwist-20230509\Similar_domain_name_detection\www.bjtu.edu.cnDNS过滤后的混淆域名.csv保存成功

# %%
domains = LSH_alg(args['domain'], domains, args['request_timeout_http'], args['useragent'], args['option_lsh'])
# Out:
# 将要进行LSH检测的域名：
#
#      fuzzer           domain         score                     dns_record
# 0  addition  www.bjut.edu.cn  0.000000e+00  27.221.108.52,116.211.138.205
# 1  addition  www.sjtu.edu.cn  4.440892e-16                  202.120.2.119
# 2  addition  www.bjmu.edu.cn  0.000000e+00                202.112.190.162
# 3  addition  www.djtu.edu.cn  1.333333e-01                202.199.128.144
# 4  addition  www.bjtu.edu.cn  0.000000e+00                202.112.154.197
# 5  addition  www.bjou.edu.cn  0.000000e+00                 111.198.125.95
# 6  addition  www.zjtu.edu.cn  4.440892e-16                  61.163.28.158
# 7  addition  www.njtu.edu.cn  1.333333e-01                202.112.154.197
# 8  addition  www.bjfu.edu.cn  0.000000e+00                 202.204.112.10
# 9  addition  www.xjtu.edu.cn  4.440892e-16                   202.117.1.13
# >www.zjtu.edu.cn的LSH得分：0
# >www.bjut.edu.cn查询出错：HTTP Error 403: Forbidden
# >www.sjtu.edu.cn的LSH得分：0
# >www.bjtu.edu.cn的LSH得分：100
# >www.bjfu.edu.cn的LSH得分：0
# >www.njtu.edu.cn的LSH得分：100
# >www.bjou.edu.cn的LSH得分：0
# >www.bjmu.edu.cn的LSH得分：0
# >www.djtu.edu.cn的LSH得分：0
# >www.xjtu.edu.cn的LSH得分：0

# %%
pd.DataFrame(domains)
# Out:
#      fuzzer           domain         score                     dns_record  \
# 0  addition  www.zjtu.edu.cn  4.440892e-16                  61.163.28.158
# 1  addition  www.bjut.edu.cn  0.000000e+00  27.221.108.52,116.211.138.205
# 2  addition  www.sjtu.edu.cn  4.440892e-16                  202.120.2.119
# 3  addition  www.bjtu.edu.cn  0.000000e+00                202.112.154.197
# 4  addition  www.bjfu.edu.cn  0.000000e+00                 202.204.112.10
# 5  addition  www.njtu.edu.cn  1.333333e-01                202.112.154.197
# 6  addition  www.bjou.edu.cn  0.000000e+00                 111.198.125.95
# 7  addition  www.bjmu.edu.cn  0.000000e+00                202.112.190.162
# 8  addition  www.djtu.edu.cn  1.333333e-01                202.199.128.144
# 9  addition  www.xjtu.edu.cn  4.440892e-16                   202.117.1.13
#
#    LSH_score
# 0          0
# 1         -1
# 2          0
# 3        100
# 4          0
# 5        100
# 6          0
# 7          0
# 8          0
# 9          0

# %%
save_domains(domains, "{}LSH过滤后的混淆域名".format(url.domain))
# Out:
# 文件：D:\Desktop\上班\dnstwist-20230509\Similar_domain_name_detection\www.bjtu.edu.cnLSH过滤后的混淆域名.csv保存成功
