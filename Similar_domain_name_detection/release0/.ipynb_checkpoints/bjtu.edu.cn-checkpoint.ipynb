# %%
# !/usr/bin/env python3
# -*- coding: utf-8 -*-

__author__ = 'laolao'
__version__ = '20230526'
__email__ = 'xxx@xxx.com'

from setuptools.package_index import user_agent
import re
import sys
import socket

import fuzzer_plus
from dependent_function import REQUEST_TIMEOUT_HTTP, _debug, UrlOpener, UrlParser, my_reshape, save_domains

socket.setdefaulttimeout(12.0)
import numpy as np
import pandas as pd
import threading
import os
import queue

try:
    import tlsh

    MODULE_TLSH = True
except ImportError as e:
    _debug(e)
    MODULE_TLSH = False

try:
    import ssdeep

    MODULE_SSDEEP = True
except ImportError as e:
    _debug(e)
    try:
        import ppdeep as ssdeep

        MODULE_SSDEEP = True
    except ImportError as e:
        _debug(e)
        MODULE_SSDEEP = False

try:
    import idna
except ImportError as e:
    _debug(e)


    class idna:
        @staticmethod
        def decode(domain):
            return domain.encode().decode('idna')

        @staticmethod
        def encode(domain):
            return domain.encode('idna')

VALID_FQDN_REGEX = re.compile(r'(?=^.{4,253}$)(^((?!-)[a-z0-9-]{1,63}(?<!-)\.)+[a-z0-9-]{2,63}$)',
                              re.IGNORECASE)  # 有效的FQDN正则表达式
USER_AGENT_STRING = 'Mozilla/5.0 ({} {}-bit) dnstwist/{}'.format(sys.platform, sys.maxsize.bit_length() + 1,
                                                                 __version__)
THREAD_COUNT_DEFAULT = min(32, os.cpu_count() + 4)


def search_dns(domains, _type=1, thread_num=4):
    ''':cvar
    _type：控制查询级别，默认查询A记录
        1：A
        2: NS
        3: MX
        4+: AAAA
    A记录，将主机名转换为IP地址；[默认]
    MX记录，邮件交换记录，定义邮件服务器的域名；
    NS记录，标记区域的域名服务器及授权子域；
    AAAA记录，ipv6
    '''
    print('Fuzzer后生成的域名：\n')
    print(pd.DataFrame(domains))
    domains = list(domains)
    from dns.resolver import Resolver
    import dns.rdatatype
    resolv = Resolver()
    if hasattr(resolv, 'resolve'):
        resolve = resolv.resolve
    else:
        resolve = resolv.query

    def __answer_to_list(_, _type):
        ''':cvar 输入域名，输出对应的dns记录'''
        try:
            if _type == 2:
                _re = resolve(_, rdtype=dns.rdatatype.NS)
            elif _type == 3:
                _re = resolve(_, rdtype=dns.rdatatype.MX)
            elif _type >= 4:
                _re = resolve(_, rdtype=dns.rdatatype.AAAA)
            else:
                _re = resolve(_, rdtype=dns.rdatatype.A)
            _ = []
            for i in _re:
                for j in str(i).split('\n'):
                    _.append(j.split(' ')[-1])
            return _
        except:
            print('>{} 解析结果：Check no record'.format(_))
            return []

    def __job_search_dns(domains, q):
        for _ in domains:
            ip_list = __answer_to_list(_['domain'], _type)
            if len(ip_list):  # 没有记录的直接过滤掉
                _['dns_record'] = ','.join(list(set(ip_list)))
                print('>{} 解析结果：{}'.format(_['domain'], _['dns_record']))
                q.put(_)

    q = queue.Queue()
    threads = []  # 线程列表
    data = my_reshape(domains, thread_num)
    for i in range(thread_num):
        t = threading.Thread(target=__job_search_dns, args=(data[i], q))
        t.start()
        threads.append(t)
    for thread in threads:
        thread.join()
    new_domains = []
    for _ in range(q.qsize()):
        new_domains.append(q.get())
    print("\nDNS查询过滤域名个数：{}->{}".format(len(domains), len(new_domains)))
    print(pd.DataFrame(new_domains))
    return new_domains


def __job_LSH_alg(domains, lsh_init, REQUEST_TIMEOUT_HTTP, option_lsh, q):
    for _ in domains:
        try:
            r = UrlOpener(UrlParser(_['domain']).full_uri(),
                          timeout=REQUEST_TIMEOUT_HTTP,
                          headers={'user-agent': user_agent},
                          verify=False)
        except Exception as e:
            print(">{}查询出错：{}".format(_['domain'], e))
            _['LSH_score'] = -1
            q.put(_)
        else:
            _['LSH_score'] = -1  # 默认值 -1
            if option_lsh == 'ssdeep':
                lsh_curr = ssdeep.hash(r.normalized_content)
                if lsh_curr not in (None, '3::'):
                    _['LSH_score'] = ssdeep.compare(lsh_init, lsh_curr)
            elif option_lsh == 'tlsh':
                lsh_curr = tlsh.hash(r.normalized_content)
                if lsh_curr not in (None, '', 'TNULL'):
                    _['LSH_score'] = int(100 - (min(tlsh.diff(lsh_init, lsh_curr), 300) / 3))
            print('>{}的LSH得分：{}'.format(_['domain'], _['LSH_score']))
            q.put(_)


def LSH_alg(url_raw, domains, REQUEST_TIMEOUT_HTTP, user_agent, option_lsh='ssdeep', thread_num=4):
    print('\n将要进行LSH检测的域名：\n')
    print(pd.DataFrame(domains))
    r = UrlOpener(UrlParser(url_raw).full_uri(),
                  timeout=REQUEST_TIMEOUT_HTTP,
                  headers={'user-agent': user_agent},
                  verify=False)
    if option_lsh == 'ssdeep':
        lsh_init = ssdeep.hash(r.normalized_content)
    else:
        lsh_init = tlsh.hash(r.normalized_content)

    q = queue.Queue()
    threads = []  # 线程列表
    data = my_reshape(domains, thread_num)

    for i in range(thread_num):
        t = threading.Thread(target=__job_LSH_alg, args=(data[i], lsh_init, REQUEST_TIMEOUT_HTTP, option_lsh, q))
        t.start()
        threads.append(t)
    for thread in threads:
        thread.join()
    new_domains = []
    for _ in range(q.qsize()):
        new_domains.append(q.get())
    return new_domains

# %%
args = {
    'all': False,
    'format': 'cli',  # csv/json/cli
    'domain': 'https://www.cnblogs.com/',
    'option_lsh': 'ssdeep',  # 使用LSH算法评估网页相似度: ssdeep, tlsh(默认:ssdeep)
    'phash': False,
    'screenshots': False,  # argument --screenshots requires --phash
    'threads': 20,
    'dns_type': 1,
    'fuzzer_num': 1000,  # 0-inf，inf代表输出所有的生成结果
    'threshold_value': 0.15,
    'tld_all': True,
    'fuzzers': [
        'addition', 'bitsquatting',
#         'cyrillic', 'homoglyph', # 这两个查不到什么有用的
        'hyphenation',
        'insertion', 'omission', 'repetition', 'replacement',
        'subdomain', 'transposition', 'vowel-swap', 'dictionary'
    ],
    'useragent': USER_AGENT_STRING,
    'request_timeout_http': REQUEST_TIMEOUT_HTTP
}

# %%
url = UrlParser(args['domain'])
fuzz = fuzzer_plus.Fuzzer(url.domain, tld_all=args['tld_all'], threshold_value=args['threshold_value'], top=args['fuzzer_num'])
fuzz.generate(args['fuzzers'])
domains = fuzz.domains

# %%
pd.DataFrame(domains)
# Out:
#        fuzzer           domain  score
# 0    addition  www.nsbgocl.com    0.0
# 1    addition  www.onbclgs.com    0.0
# 2    addition  www.lnbogcs.com    0.0
# 3    addition  www.lcsbngo.com    0.0
# 4    addition  www.sngblco.com    0.0
# ..        ...              ...    ...
# 995  addition  www.csglobn.com    0.0
# 996  addition  www.obglscn.com    0.0
# 997  addition  www.scgnbol.com    0.0
# 998  addition  www.lgbnosc.com    0.0
# 999  addition  www.gcbolns.com    0.0
#
# [1000 rows x 3 columns]

# %%
save_domains(domains, "{}生成的混淆域名".format(url.domain))
# Out:
# 文件：D:\Desktop\上班\dnstwist-20230509\Similar_domain_name_detection\www.cnblogs.com生成的混淆域名.csv保存成功

# %%
fuzz._make_fig(url.domain)

# %%
domains = search_dns(domains, _type=args['dns_type'], thread_num=args['threads'])
# Out:
# Fuzzer后生成的域名：
#
#        fuzzer           domain  score
# 0    addition  www.nsbgocl.com    0.0
# 1    addition  www.onbclgs.com    0.0
# 2    addition  www.lnbogcs.com    0.0
# 3    addition  www.lcsbngo.com    0.0
# 4    addition  www.sngblco.com    0.0
# ..        ...              ...    ...
# 995  addition  www.csglobn.com    0.0
# 996  addition  www.obglscn.com    0.0
# 997  addition  www.scgnbol.com    0.0
# 998  addition  www.lgbnosc.com    0.0
# 999  addition  www.gcbolns.com    0.0
#
# [1000 rows x 3 columns]
# >www.clonbgs.com 解析结果：Check no record
# >www.cꞑḅlogs.com 解析结果：Check no record
# >www.nlsgobc.com 解析结果：Check no record>www.cnblois.com 解析结果：Check no record
#
# >www.lbcosgn.com 解析结果：Check no record
# >www.cglonsb.com 解析结果：Check no record
# >www.cṅbɫogs.com 解析结果：Check no record
# >www.nsogbcl.com 解析结果：Check no record
# >www.nsbgocl.com 解析结果：Check no record
# >www.nobcgls.com 解析结果：Check no record
# >www.ognbslc.com 解析结果：Check no record
# >www.cobnlgs.com 解析结果：Check no record>www.bnosgcl.com 解析结果：Check no record
#
# >www.cnhlogs.com 解析结果：198.54.117.217,198.54.117.212,198.54.117.210
# >www.cgnbols.com 解析结果：Check no record
# >www.gslonbc.com 解析结果：Check no record
# >www.lnobcgs.com 解析结果：Check no record
# >www.golbsnc.com 解析结果：Check no record
# >www.lsnocgb.com 解析结果：Check no record
# >www.csnolbg.com 解析结果：Check no record
# >www.ogcnbsl.com 解析结果：Check no record
# >www.golcbsn.com 解析结果：Check no record
# >www.onbclgs.com 解析结果：Check no record
# >www.solgbnc.com 解析结果：Check no record
# >www.olscngb.com 解析结果：Check no record
# >www.lcgnbso.com 解析结果：Check no record
# >www.scbngol.com 解析结果：Check no record
# >www.gsbolnc.com 解析结果：Check no record
# >www.crḇlogs.com 解析结果：Check no record
# >www.cnʙloǵs.com 解析结果：Check no record
# >www.cblsnog.com 解析结果：Check no record
# >www.bosglcn.com 解析结果：Check no record
# >www.gsnlcob.com 解析结果：Check no record
# >www.cņblogś.com 解析结果：Check no record
# >www.cńḇlogs.com 解析结果：Check no record
# >www.sgcolnb.com 解析结果：Check no record
# >www.glcsonb.com 解析结果：Check no record
# >www.bsnolgc.com 解析结果：Check no record
# >www.nosbcgl.com 解析结果：Check no record
# >www.ogbcnls.com 解析结果：Check no record
# >www.scnbogl.com 解析结果：Check no record
# >www.lnbogcs.com 解析结果：Check no record>www.bogcnls.com 解析结果：Check no record
# >www.osblcng.com 解析结果：Check no record>www.sbloncg.com 解析结果：Check no record
#
#
# >www.cnƅloğs.com 解析结果：Check no record
# >www.gnobcsl.com 解析结果：Check no record
# >www.lnogcbs.com 解析结果：Check no record
# >www.cṉƅlogs.com 解析结果：Check no record
# >www.slongbc.com 解析结果：Check no record
# >www.obcngls.com 解析结果：Check no record
# >www.gsbnocl.com 解析结果：Check no record
# >www.clsognb.com 解析结果：Check no record
# >www.cńbloġs.com 解析结果：Check no record
# >www.oncsbgl.com 解析结果：Check no record
# >www.olgbscn.com 解析结果：Check no record
# >www.lcsbngo.com 解析结果：Check no record
# >www.lgbonsc.com 解析结果：Check no record
# >www.gsncblo.com 解析结果：Check no record
# >www.coglsbn.com 解析结果：Check no record
# >www.nclgosb.com 解析结果：Check no record
# >www.glncsob.com 解析结果：Check no record
# >www.lnbosgc.com 解析结果：Check no record
# >www.lsngboc.com 解析结果：Check no record
# >www.cgsobln.com 解析结果：Check no record
# >www.bnlgcos.com 解析结果：Check no record
# >www.gcolbns.com 解析结果：Check no record
# >www.scnlobg.com 解析结果：Check no record
# >www.nbcolsg.com 解析结果：Check no record
# >www.gbncsol.com 解析结果：Check no record
# >www.bcongsl.com 解析结果：Check no record
# >www.cmblọgs.com 解析结果：Check no record
# >www.nsolgbc.com 解析结果：Check no record
# >www.cnḃlogś.com 解析结果：Check no record
# >www.bsoglcn.com 解析结果：Check no record
# >www.colnbgs.com 解析结果：Check no record
# >www.loncgbs.com 解析结果：Check no record
# >www.cbosngl.com 解析结果：Check no record
# >www.bonslgc.com 解析结果：Check no record
# >www.nsgbolc.com 解析结果：Check no record
# >www.sngblco.com 解析结果：Check no record
# >www.sgocbnl.com 解析结果：Check no record
# >www.gbcnlos.com 解析结果：Check no record
# >www.cṅblogś.com 解析结果：Check no record
# >www.ogblcns.com 解析结果：Check no record
# >www.sblngco.com 解析结果：34.102.136.180
# >www.cndloǧs.com 解析结果：Check no record
# >www.lbgcons.com 解析结果：Check no record
# >www.lgobcns.com 解析结果：Check no record
# >www.gslbcno.com 解析结果：Check no record
# >www.ongbcls.com 解析结果：Check no record
# >www.bsgcoln.com 解析结果：Check no record
# >www.ocnlbgs.com 解析结果：Check no record
# >www.ngobslc.com 解析结果：Check no record
# >www.slcobng.com 解析结果：Check no record
# >www.lnbgosc.com 解析结果：Check no record
# >www.onblcgs.com 解析结果：Check no record
# >www.scbolgn.com 解析结果：Check no record
# >www.conblsg.com 解析结果：Check no record
# >www.gcblnos.com 解析结果：Check no record
# >www.bclsnog.com 解析结果：Check no record
# >www.sonlgbc.com 解析结果：Check no record
# >www.glcnsbo.com 解析结果：Check no record
# >www.gsbolcn.com 解析结果：Check no record
# >www.gcslobn.com 解析结果：Check no record
# >www.lngobsc.com 解析结果：Check no record
# >www.slgnboc.com 解析结果：Check no record
# >www.boscngl.com 解析结果：Check no record
# >www.bcsnlog.com 解析结果：Check no record
# >www.snboglc.com 解析结果：Check no record
# >www.nbsgcol.com 解析结果：Check no record
# >www.bgscoln.com 解析结果：Check no record
# >www.sgolncb.com 解析结果：Check no record
# >www.bscglno.com 解析结果：Check no record
# >www.oslnbgc.com 解析结果：Check no record
# >www.nbslcog.com 解析结果：Check no record
# >www.cnbǐogs.com 解析结果：Check no record
# >www.bncolgs.com 解析结果：Check no record
# >www.snlcbgo.com 解析结果：Check no record
# >www.bgclsno.com 解析结果：Check no record
# >www.lgcsbon.com 解析结果：Check no record>www.ocsbngl.com 解析结果：Check no record
#
# >www.gnscblo.com 解析结果：Check no record
# >www.nclgbos.com 解析结果：Check no record
# >www.lbogcns.com 解析结果：Check no record
# >www.lngbcso.com 解析结果：Check no record
# >www.cngoslb.com 解析结果：Check no record
# >www.sobglcn.com 解析结果：Check no record
# >www.ncolgbs.com 解析结果：Check no record
# >www.slbncog.com 解析结果：Check no record
# >www.cnƅɫogs.com 解析结果：Check no record
# >www.nsoclgb.com 解析结果：Check no record
# >www.bclnosg.com 解析结果：Check no record
# >www.gbcsoln.com 解析结果：Check no record
# >www.ogcsbln.com 解析结果：Check no record
# >www.osbcgln.com 解析结果：Check no record
# >www.lgsocnb.com 解析结果：Check no record
# >www.bgnlosc.com 解析结果：Check no record
# >www.cslbogn.com 解析结果：Check no record
# >www.bcnslog.com 解析结果：Check no record
# >www.ocslgnb.com 解析结果：Check no record
# >www.ncglobs.com 解析结果：Check no record
# >www.cgobsnl.com 解析结果：Check no record
# >www.scnlgbo.com 解析结果：Check no record
# >www.onbscgl.com 解析结果：Check no record
# >www.blncosg.com 解析结果：Check no record
# >www.sgcblno.com 解析结果：Check no record
# >www.lgbosnc.com 解析结果：Check no record
# >www.cṅbloɡs.com 解析结果：Check no record
# >www.lobsncg.com 解析结果：Check no record
# >www.lbcogsn.com 解析结果：Check no record
# >www.songcbl.com 解析结果：Check no record
# >www.clnsobg.com 解析结果：Check no record
# >www.crbloǵs.com 解析结果：Check no record
# >www.bsocgln.com 解析结果：Check no record
# >www.blcgosn.com 解析结果：Check no record
# >www.lcsongb.com 解析结果：Check no record
# >www.cnblogs.com 解析结果：114.55.187.58,101.37.115.180,114.55.205.139
# >www.bgolcns.com 解析结果：Check no record
# >www.nlsocgb.com 解析结果：Check no record
# >www.gbocnls.com 解析结果：Check no record
# >www.bosgcnl.com 解析结果：Check no record
# >www.cnbloqꜱ.com 解析结果：Check no record
# >www.sglcnbo.com 解析结果：Check no record
# >www.cnbɫogś.com 解析结果：Check no record
# >www.nclsogb.com 解析结果：Check no record
# >www.obsclng.com 解析结果：Check no record
# >www.bngcols.com 解析结果：Check no record
# >www.onbsglc.com 解析结果：Check no record
# >www.olsnbcg.com 解析结果：Check no record
# >www.cosbngl.com 解析结果：Check no record
# >www.osnbglc.com 解析结果：Check no record
# >www.bsclnog.com 解析结果：Check no record
# >www.bscgnlo.com 解析结果：Check no record
# >www.olncbgs.com 解析结果：Check no record
# >www.sgbolcn.com 解析结果：Check no record
# >www.onclbgs.com 解析结果：Check no record
# >www.ncbsgol.com 解析结果：Check no record
# >www.lgcsobn.com 解析结果：Check no record
# >www.cnbzogs.com 解析结果：Check no record
# >www.logcnbs.com 解析结果：Check no record
# >www.oclsgbn.com 解析结果：Check no record
# >www.sblgnoc.com 解析结果：Check no record
# >www.gnocslb.com 解析结果：Check no record
# >www.lbocsgn.com 解析结果：Check no record
# >www.nblcsgo.com 解析结果：Check no record
# >www.lcsgonb.com 解析结果：Check no record
# >www.bonlgsc.com 解析结果：Check no record
# >www.cbgnlos.com 解析结果：Check no record
# >www.onlbgsc.com 解析结果：Check no record
# >www.slocbgn.com 解析结果：Check no record
# >www.lgcbsno.com 解析结果：Check no record
# >www.glcsnbo.com 解析结果：Check no record
# >www.nblscog.com 解析结果：Check no record
# >www.cgonbls.com 解析结果：Check no record
# >www.lgbscno.com 解析结果：Check no record
# >www.sblogcn.com 解析结果：Check no record
# >www.lcsnbog.com 解析结果：Check no record
# >www.lsgbonc.com 解析结果：Check no record
# >www.clbgsno.com 解析结果：Check no record
# >www.cobslgn.com 解析结果：Check no record
# >www.bloscgn.com 解析结果：Check no record
# >www.lbsoncg.com 解析结果：Check no record
# >www.glnbsco.com 解析结果：Check no record
# >www.csbngol.com 解析结果：Check no record
# >www.gslnocb.com 解析结果：Check no record
# >www.nlogsbc.com 解析结果：Check no record
# >www.gsnolbc.com 解析结果：Check no record
# >www.olncsbg.com 解析结果：Check no record
# >www.nlogbsc.com 解析结果：Check no record
# >www.sonclgb.com 解析结果：Check no record
# >www.bognscl.com 解析结果：Check no record
# >www.ogncsbl.com 解析结果：Check no record
# >www.soblngc.com 解析结果：Check no record
# >www.lsocngb.com 解析结果：Check no record
# >www.blcgson.com 解析结果：Check no record
# >www.clbsgon.com 解析结果：Check no record
# >www.cṅƅlogs.com 解析结果：Check no record
# >www.cņblogʂ.com 解析结果：Check no record
# >www.sgcnlob.com 解析结果：Check no record
# >www.ogbsnlc.com 解析结果：Check no record
# >www.cnbloɢŝ.com 解析结果：Check no record
# >www.gosblnc.com 解析结果：Check no record
# >www.gconlsb.com 解析结果：Check no record
# >www.lbcongs.com 解析结果：Check no record
# >www.blcongs.com 解析结果：Check no record
# >www.nclgobs.com 解析结果：Check no record
# >www.boscnlg.com 解析结果：Check no record
# >www.lcgsbno.com 解析结果：Check no record
# >www.cgbsnlo.com 解析结果：Check no record
# >www.cnḅlogś.com 解析结果：Check no record
# >www.bonlsgc.com 解析结果：Check no record
# >www.cslobng.com 解析结果：Check no record
# >www.lobscgn.com 解析结果：Check no record
# >www.clongsb.com 解析结果：Check no record
# >www.bconslg.com 解析结果：Check no record
# >www.slnobcg.com 解析结果：Check no record
# >www.osglncb.com 解析结果：Check no record
# >www.bngocsl.com 解析结果：Check no record
# >www.blgcnso.com 解析结果：Check no record
# >www.sglnobc.com 解析结果：Check no record
# >www.slogbcn.com 解析结果：Check no record
# >www.cnsolbg.com 解析结果：Check no record
# >www.gbscoln.com 解析结果：Check no record
# >www.olgnscb.com 解析结果：Check no record
# >www.cobngsl.com 解析结果：Check no record
# >www.cblsgon.com 解析结果：Check no record>www.olcnbgs.com 解析结果：Check no record
#
# >www.bglnsco.com 解析结果：Check no record
# >www.nosclgb.com 解析结果：Check no record
# >www.noblscg.com 解析结果：Check no record
# >www.lsbognc.com 解析结果：Check no record
# >www.nsgblco.com 解析结果：Check no record
# >www.bgsocnl.com 解析结果：Check no record
# >www.ocgslbn.com 解析结果：Check no record
# >www.ncbogls.com 解析结果：Check no record
# >www.gbolcns.com 解析结果：Check no record
# >www.lcnbgso.com 解析结果：Check no record
# >www.cobslng.com 解析结果：Check no record
# >www.glcobsn.com 解析结果：Check no record
# >www.cgsolbn.com 解析结果：Check no record
# >www.cnbľoɡs.com 解析结果：Check no record
# >www.gobsnlc.com 解析结果：Check no record
# >www.clbgnso.com 解析结果：Check no record
# >www.ngclbos.com 解析结果：Check no record
# >www.nbolcsg.com 解析结果：Check no record
# >www.gnocbsl.com 解析结果：Check no record
# >www.nlcogsb.com 解析结果：Check no record
# >www.soclbgn.com 解析结果：Check no record
# >www.ocnslgb.com 解析结果：Check no record
# >www.gcsonlb.com 解析结果：Check no record
# >www.cṉbĺogs.com 解析结果：Check no record
# >www.bnscglo.com 解析结果：Check no record>www.cogsnbl.com 解析结果：Check no record
#
# >www.glcsbno.com 解析结果：Check no record
# >www.blngsco.com 解析结果：Check no record
# >www.gonbcsl.com 解析结果：Check no record
# >www.sblcogn.com 解析结果：Check no record
# >www.cndľogs.com 解析结果：Check no record
# >www.gcnlbso.com 解析结果：Check no record
# >www.consglb.com 解析结果：Check no record
# >www.lgsbcno.com 解析结果：Check no record
# >www.lgcnsbo.com 解析结果：Check no record
# >www.ncsblog.com 解析结果：34.205.242.146,54.161.222.85
# >www.slobcng.com 解析结果：Check no record
# >www.cñbloǥs.com 解析结果：Check no record
# >www.gsbnlco.com 解析结果：Check no record
# >www.bnglosc.com 解析结果：Check no record
# >www.sglbcon.com 解析结果：Check no record
# >www.lsgnboc.com 解析结果：Check no record
# >www.sngcolb.com 解析结果：Check no record
# >www.lscbgon.com 解析结果：Check no record
# >www.cnblmgs.com 解析结果：Check no record
# >www.clbnsog.com 解析结果：Check no record
# >www.crblogş.com 解析结果：Check no record
# >www.cńbłogs.com 解析结果：Check no record
# >www.lnosgbc.com 解析结果：Check no record
# >www.cbolsgn.com 解析结果：Check no record
# >www.bosngcl.com 解析结果：Check no record
# >www.lbgnsoc.com 解析结果：Check no record
# >www.lcbsogn.com 解析结果：Check no record
# >www.glconbs.com 解析结果：Check no record
# >www.csolnbg.com 解析结果：Check no record
# >www.nlbosgc.com 解析结果：Check no record
# >www.songlcb.com 解析结果：Check no record
# >www.slgbonc.com 解析结果：Check no record
# >www.cńdlogs.com 解析结果：Check no record
# >www.cnḅɫogs.com 解析结果：Check no record
# >www.olsnbgc.com 解析结果：Check no record
# >www.lsngcob.com 解析结果：Check no record
# >www.nglcobs.com 解析结果：Check no record
# >www.clgobsn.com 解析结果：Check no record
# >www.ngsbolc.com 解析结果：Check no record
# >www.ncbgols.com 解析结果：Check no record
# >www.sclbogn.com 解析结果：Check no record
# >www.sclnogb.com 解析结果：Check no record
# >www.cņbľogs.com 解析结果：Check no record
# >www.sclngob.com 解析结果：Check no record
# >www.bolsngc.com 解析结果：Check no record
# >www.cṇbloǵs.com 解析结果：Check no record
# >www.cŋbłogs.com 解析结果：Check no record
# >www.lcbngos.com 解析结果：Check no record
# >www.cnbloǧʂ.com 解析结果：Check no record
# >www.cꞑʙlogs.com 解析结果：Check no record
# >www.clgbson.com 解析结果：Check no record
# >www.gsnocbl.com 解析结果：Check no record>www.slnbcog.com 解析结果：Check no record
#
# >www.gocbsln.com 解析结果：Check no record
# >www.oscbgnl.com 解析结果：Check no record
# >www.lnbsogc.com 解析结果：Check no record
# >www.glnbsoc.com 解析结果：Check no record
# >www.oblgsnc.com 解析结果：Check no record
# >www.snogbcl.com 解析结果：Check no record
# >www.sogblcn.com 解析结果：Check no record
# >www.cblnogs.com 解析结果：Check no record
# >www.sgoblcn.com 解析结果：Check no record
# >www.bolscng.com 解析结果：Check no record
# >www.gcobsnl.com 解析结果：Check no record
# >www.ogclsnb.com 解析结果：Check no record
# >www.cnbloɡș.com 解析结果：Check no record
# >www.lbosgnc.com 解析结果：Check no record
# >www.scgonbl.com 解析结果：Check no record
# >www.bcnlsog.com 解析结果：Check no record
# >www.ngcslob.com 解析结果：Check no record
# >www.lbocgns.com 解析结果：Check no record
# >www.olgsnbc.com 解析结果：Check no record
# >www.gbolnsc.com 解析结果：Check no record
# >www.gcnlbos.com 解析结果：Check no record
# >www.glsncob.com 解析结果：Check no record
# >www.gbsconl.com 解析结果：Check no record
# >www.obgnscl.com 解析结果：Check no record
# >www.onlgcbs.com 解析结果：Check no record
# >www.gsonclb.com 解析结果：Check no record
# >www.sblncgo.com 解析结果：Check no record
# >www.cŋbľogs.com 解析结果：Check no record
# >www.lsonbgc.com 解析结果：Check no record
# >www.gosncbl.com 解析结果：Check no record
# >www.lbgncos.com 解析结果：Check no record
# >www.lbsncog.com 解析结果：Check no record
# >www.cngbols.com 解析结果：Check no record
# >www.gnclbos.com 解析结果：Check no record
# >www.gslocbn.com 解析结果：Check no record
# >www.bglsnco.com 解析结果：Check no record
# >www.slcngbo.com 解析结果：Check no record
# >www.sobnclg.com 解析结果：Check no record
# >www.cńḃlogs.com 解析结果：Check no record
# >www.bgocnsl.com 解析结果：Check no record
# >www.cŋblogs.com 解析结果：Check no record
# >www.sglcobn.com 解析结果：Check no record
# >www.bsnlcgo.com 解析结果：Check no record
# >www.cboslgn.com 解析结果：Check no record
# >www.gcoslbn.com 解析结果：Check no record
# >www.sglobnc.com 解析结果：Check no record
# >www.lconbsg.com 解析结果：Check no record
# >www.gbclnos.com 解析结果：Check no record
# >www.cgsnbol.com 解析结果：Check no record
# >www.nocgslb.com 解析结果：Check no record
# >www.ncosglb.com 解析结果：Check no record
# >www.clgonbs.com 解析结果：Check no record
# >www.sgbcoln.com 解析结果：Check no record
# >www.bnscogl.com 解析结果：Check no record
# >www.osblcgn.com 解析结果：Check no record
# >www.sbgocln.com 解析结果：Check no record
# >www.bsclong.com 解析结果：Check no record
# >www.cńblogş.com 解析结果：Check no record
# >www.bcnsgol.com 解析结果：Check no record
# >www.glocsbn.com 解析结果：Check no record
# >www.ngsbocl.com 解析结果：Check no record
# >www.gsoclbn.com 解析结果：Check no record
# >www.sloncgb.com 解析结果：Check no record
# >www.scnolbg.com 解析结果：Check no record
# >www.bogslcn.com 解析结果：Check no record
# >www.gsblnco.com 解析结果：Check no record
# >www.ncgbols.com 解析结果：Check no record
# >www.bslgcon.com 解析结果：Check no record
# >www.nsgbocl.com 解析结果：Check no record
# >www.scgnolb.com 解析结果：Check no record
# >www.cnbloqṡ.com 解析结果：Check no record
# >www.lgsnbco.com 解析结果：Check no record
# >www.obgsncl.com 解析结果：Check no record
# >www.scogbln.com 解析结果：Check no record
# >www.sgnlboc.com 解析结果：Check no record
# >www.cnḋlogs.com 解析结果：Check no record
# >www.ncbgosl.com 解析结果：Check no record
# >www.gbnsloc.com 解析结果：Check no record
# >www.locgnbs.com 解析结果：Check no record
# >www.slgcbno.com 解析结果：Check no record
# >www.lgbcosn.com 解析结果：Check no record
# >www.gbclosn.com 解析结果：Check no record
# >www.ngbsolc.com 解析结果：Check no record
# >www.colbsng.com 解析结果：Check no record
# >www.lsgbcno.com 解析结果：Check no record
# >www.bgconsl.com 解析结果：Check no record
# >www.noblsgc.com 解析结果：Check no record
# >www.gscnolb.com 解析结果：Check no record
# >www.osngblc.com 解析结果：Check no record
# >www.slcgobn.com 解析结果：Check no record
# >www.bgnoslc.com 解析结果：Check no record
# >www.obncgsl.com 解析结果：Check no record
# >www.nlsogbc.com 解析结果：Check no record
# >www.lbncosg.com 解析结果：Check no record
# >www.lgbsnco.com 解析结果：Check no record
# >www.bolcsgn.com 解析结果：Check no record
# >www.gsbclon.com 解析结果：Check no record
# >www.cnƅļogs.com 解析结果：Check no record
# >www.ocbsngl.com 解析结果：Check no record
# >www.bcgsnol.com 解析结果：Check no record
# >www.nslgocb.com 解析结果：Check no record
# >www.nlcsbgo.com 解析结果：Check no record
# >www.nlocbgs.com 解析结果：Check no record
# >www.glsobcn.com 解析结果：Check no record
# >www.cṇbloĝs.com 解析结果：Check no record
# >www.ncslogb.com 解析结果：Check no record
# >www.cnbȋogs.com 解析结果：Check no record
# >www.nblsgco.com 解析结果：Check no record
# >www.cņbloĝs.com 解析结果：Check no record
# >www.ocgsnbl.com 解析结果：Check no record
# >www.blnsgco.com 解析结果：Check no record
# >www.lobgnsc.com 解析结果：Check no record
# >www.bcgonsl.com 解析结果：Check no record
# >www.oscnglb.com 解析结果：Check no record
# >www.golcbns.com 解析结果：Check no record
# >www.lsonbcg.com 解析结果：Check no record
# >www.ocbnsgl.com 解析结果：Check no record
# >www.bnolgsc.com 解析结果：Check no record
# >www.cglnbso.com 解析结果：Check no record
# >www.scnlbog.com 解析结果：Check no record
# >www.sbolgcn.com 解析结果：Check no record
# >www.bsngcol.com 解析结果：Check no record
# >www.oglnsbc.com 解析结果：Check no record
# >www.lbngsoc.com 解析结果：Check no record
# >www.c4blogs.com 解析结果：Check no record
# >www.bnlosgc.com 解析结果：Check no record
# >www.csbonlg.com 解析结果：Check no record
# >www.bgsnolc.com 解析结果：Check no record
# >www.gbnoscl.com 解析结果：Check no record
# >www.oncbslg.com 解析结果：Check no record
# >www.snbcogl.com 解析结果：Check no record
# >www.globscn.com 解析结果：Check no record
# >www.clgbnos.com 解析结果：Check no record
# >www.glbcson.com 解析结果：Check no record
# >www.sbnlgoc.com 解析结果：Check no record
# >www.oncgslb.com 解析结果：Check no record
# >www.cnsbgol.com 解析结果：Check no record
# >www.bclogns.com 解析结果：Check no record
# >www.cbolngs.com 解析结果：Check no record
# >www.ncbgsol.com 解析结果：Check no record
# >www.gsnoblc.com 解析结果：Check no record
# >www.cbnsgol.com 解析结果：Check no record
# >www.nbcsgol.com 解析结果：Check no record
# >www.gcnbosl.com 解析结果：Check no record
# >www.bnlocsg.com 解析结果：Check no record
# >www.nlcsogb.com 解析结果：Check no record
# >www.solbcgn.com 解析结果：Check no record
# >www.ncboslg.com 解析结果：Check no record
# >www.coslgnb.com 解析结果：Check no record
# >www.bnolcgs.com 解析结果：Check no record
# >www.blgonsc.com 解析结果：Check no record
# >www.obcglsn.com 解析结果：Check no record
# >www.glsnbco.com 解析结果：Check no record
# >www.gcobnsl.com 解析结果：Check no record
# >www.lgcbnos.com 解析结果：Check no record
# >www.lcobngs.com 解析结果：Check no record
# >www.cogbnsl.com 解析结果：Check no record
# >www.slboncg.com 解析结果：Check no record
# >www.loncgsb.com 解析结果：Check no record
# >www.ogbnlsc.com 解析结果：Check no record
# >www.blgnsco.com 解析结果：Check no record
# >www.nbcgslo.com 解析结果：Check no record
# >www.lscgonb.com 解析结果：Check no record
# >www.nsolbgc.com 解析结果：Check no record
# >www.cnbloǵʂ.com 解析结果：Check no record
# >www.bslognc.com 解析结果：Check no record
# >www.sclognb.com 解析结果：Check no record
# >www.cogsnlb.com 解析结果：Check no record
# >www.sgcobln.com 解析结果：Check no record
# >www.sclgbno.com 解析结果：Check no record
# >www.clgsobn.com 解析结果：Check no record
# >www.sblgonc.com 解析结果：Check no record
# >www.lscgbno.com 解析结果：Check no record
# >www.bncglso.com 解析结果：Check no record
# >www.slcbong.com 解析结果：Check no record
# >www.nolbcsg.com 解析结果：Check no record
# >www.ocbsnlg.com 解析结果：Check no record
# >www.obclnsg.com 解析结果：Check no record
# >www.ognbcls.com 解析结果：Check no record
# >www.blosgnc.com 解析结果：Check no record
# >www.olsncgb.com 解析结果：Check no record
# >www.lobnscg.com 解析结果：Check no record
# >www.ocsnlgb.com 解析结果：Check no record
# >www.cṉblogʂ.com 解析结果：Check no record
# >www.sclnobg.com 解析结果：Check no record
# >www.oslgncb.com 解析结果：Check no record
# >www.lgnsbco.com 解析结果：Check no record
# >www.cgblson.com 解析结果：Check no record
# >www.bgncslo.com 解析结果：Check no record
# >www.gsobcnl.com 解析结果：Check no record
# >www.nglbsoc.com 解析结果：Check no record
# >www.lngcsbo.com 解析结果：Check no record
# >www.bcosgnl.com 解析结果：Check no record
# >www.closgnb.com 解析结果：Check no record
# >www.gbnsclo.com 解析结果：Check no record
# >www.cngsblo.com 解析结果：Check no record
# >www.cnbfogs.com 解析结果：Check no record
# >www.locbgsn.com 解析结果：Check no record
# >www.cnglbso.com 解析结果：Check no record
# >www.blcosng.com 解析结果：Check no record
# >www.gsonlcb.com 解析结果：Check no record
# >www.ngoclbs.com 解析结果：Check no record
# >www.bgcsnlo.com 解析结果：Check no record
# >www.lgbcnos.com 解析结果：Check no record
# >www.ngblosc.com 解析结果：Check no record
# >www.cnsbglo.com 解析结果：Check no record
# >www.cnƅlogś.com 解析结果：Check no record
# >www.slbgcon.com 解析结果：Check no record
# >www.ocblsng.com 解析结果：Check no record
# >www.blocnsg.com 解析结果：Check no record
# >www.gsnlcbo.com 解析结果：Check no record
# >www.lscnbog.com 解析结果：Check no record
# >www.slgobcn.com 解析结果：Check no record
# >www.cnḅloɡs.com 解析结果：Check no record
# >www.gloscnb.com 解析结果：Check no record
# >www.cgsbnlo.com 解析结果：Check no record
# >www.osglbnc.com 解析结果：Check no record
# >www.ngbsloc.com 解析结果：Check no record
# >www.olgcbsn.com 解析结果：Check no record
# >www.gbsclno.com 解析结果：Check no record
# >www.bglsocn.com 解析结果：Check no record
# >www.consblg.com 解析结果：Check no record
# >www.cogsbln.com 解析结果：Check no record
# >www.cgnlsob.com 解析结果：Check no record
# >www.bsolgnc.com 解析结果：Check no record
# >www.lbgsocn.com 解析结果：Check no record
# >www.olsngbc.com 解析结果：Check no record
# >www.bscolgn.com 解析结果：Check no record
# >www.lonsgbc.com 解析结果：Check no record
# >www.bnsgcol.com 解析结果：Check no record
# >www.cnbłoǧs.com 解析结果：Check no record
# >www.lcgnbos.com 解析结果：Check no record
# >www.glcbnso.com 解析结果：Check no record
# >www.sogbnlc.com 解析结果：Check no record
# >www.nsgcobl.com 解析结果：Check no record
# >www.sclbgon.com 解析结果：Check no record
# >www.sognblc.com 解析结果：Check no record
# >www.nlsbocg.com 解析结果：Check no record
# >www.gnlbsoc.com 解析结果：Check no record
# >www.nsbglco.com 解析结果：Check no record
# >www.onblcsg.com 解析结果：Check no record
# >www.gcsblon.com 解析结果：Check no record
# >www.ogcbsnl.com 解析结果：Check no record
# >www.cnbĺogʂ.com 解析结果：Check no record
# >www.sncglbo.com 解析结果：Check no record
# >www.ngbclos.com 解析结果：Check no record
# >www.cbglnos.com 解析结果：Check no record
# >www.cnplogs.com 解析结果：Check no record
# >www.nbgcosl.com 解析结果：Check no record
# >www.cndloǵs.com 解析结果：Check no record
# >www.ncoslgb.com 解析结果：Check no record
# >www.gsclbno.com 解析结果：Check no record
# >www.csnlbog.com 解析结果：Check no record
# >www.blscgon.com 解析结果：Check no record
# >www.gonlbcs.com 解析结果：Check no record
# >www.sgcblon.com 解析结果：Check no record
# >www.nbscglo.com 解析结果：Check no record
# >www.onsgcbl.com 解析结果：Check no record
# >www.cnbɩogs.com 解析结果：Check no record
# >www.lsgbnoc.com 解析结果：Check no record
# >www.cnƅloɡs.com 解析结果：Check no record
# >www.gsconlb.com 解析结果：Check no record
# >www.ogcsnlb.com 解析结果：Check no record
# >www.cosgbln.com 解析结果：Check no record
# >www.gcblosn.com 解析结果：Check no record
# >www.blgcsno.com 解析结果：Check no record
# >www.glcnosb.com 解析结果：Check no record
# >www.nsglocb.com 解析结果：Check no record
# >www.colsnbg.com 解析结果：Check no record
# >www.ncslgob.com 解析结果：Check no record
# >www.gsbnloc.com 解析结果：Check no record
# >www.oscgnlb.com 解析结果：Check no record
# >www.osglbcn.com 解析结果：Check no record
# >www.oscblng.com 解析结果：Check no record
# >www.nslcobg.com 解析结果：Check no record
# >www.sbcglno.com 解析结果：Check no record
# >www.olgbncs.com 解析结果：Check no record
# >www.lobscng.com 解析结果：Check no record
# >www.gnscolb.com 解析结果：Check no record
# >www.gobscnl.com 解析结果：Check no record
# >www.bonlscg.com 解析结果：Check no record
# >www.cnḃlogṣ.com 解析结果：Check no record
# >www.lgobnsc.com 解析结果：Check no record
# >www.nglobsc.com 解析结果：Check no record
# >www.snblcog.com 解析结果：Check no record
# >www.noslbcg.com 解析结果：Check no record
# >www.bsnlgoc.com 解析结果：Check no record
# >www.slbnogc.com 解析结果：Check no record
# >www.scblogn.com 解析结果：Check no record
# >www.obsgncl.com 解析结果：Check no record
# >www.cnsolgb.com 解析结果：Check no record
# >www.ncsbglo.com 解析结果：Check no record
# >www.lcogsbn.com 解析结果：Check no record
# >www.blcsgno.com 解析结果：Check no record
# >www.nscolbg.com 解析结果：Check no record
# >www.cn-logs.com 解析结果：Check no record
# >www.snoblgc.com 解析结果：Check no record
# >www.gsobcln.com 解析结果：Check no record
# >www.cnbloǵş.com 解析结果：Check no record
# >www.ocngslb.com 解析结果：Check no record
# >www.clobgns.com 解析结果：Check no record
# >www.coblngs.com 解析结果：Check no record
# >www.lcnbogs.com 解析结果：Check no record
# >www.oclbsng.com 解析结果：Check no record
# >www.gsolcbn.com 解析结果：Check no record
# >www.cnʙloǧs.com 解析结果：Check no record
# >www.cnbĺoɡs.com 解析结果：Check no record
# >www.lscbgno.com 解析结果：Check no record
# >www.sgoclbn.com 解析结果：Check no record
# >www.cnʙlogs.com 解析结果：Check no record
# >www.cgonlsb.com 解析结果：Check no record
# >www.lbconsg.com 解析结果：Check no record
# >www.sobcgnl.com 解析结果：Check no record
# >www.cglnbos.com 解析结果：Check no record
# >www.clogbsn.com 解析结果：Check no record
# >www.snbolcg.com 解析结果：Check no record
# >www.bsgncol.com 解析结果：Check no record
# >www.gbonscl.com 解析结果：Check no record
# >www.sgnlcbo.com 解析结果：Check no record
# >www.nsclbgo.com 解析结果：Check no record
# >www.nblcosg.com 解析结果：Check no record
# >www.clbsngo.com 解析结果：Check no record
# >www.cbngosl.com 解析结果：Check no record
# >www.gblsonc.com 解析结果：Check no record
# >www.gnbocls.com 解析结果：Check no record
# >www.lbgnosc.com 解析结果：Check no record
# >www.cnsoblg.com 解析结果：Check no record
# >www.sbnlgco.com 解析结果：Check no record
# >www.clsgbno.com 解析结果：Check no record
# >www.glnocsb.com 解析结果：Check no record
# >www.noclsbg.com 解析结果：Check no record
# >www.nslocbg.com 解析结果：Check no record
# >www.onslgbc.com 解析结果：Check no record
# >www.gobclsn.com 解析结果：Check no record
# >www.lgocnsb.com 解析结果：Check no record
# >www.cnbɫogş.com 解析结果：Check no record
# >www.nscgobl.com 解析结果：Check no record
# >www.ngslbco.com 解析结果：Check no record
# >www.cnglsob.com 解析结果：Check no record
# >www.nocslbg.com 解析结果：Check no record
# >www.cnbloɡş.com 解析结果：Check no record
# >www.bgocsnl.com 解析结果：Check no record
# >www.olnbcsg.com 解析结果：Check no record
# >www.lbgocsn.com 解析结果：Check no record
# >www.csnobgl.com 解析结果：Check no record
# >www.bolngcs.com 解析结果：Check no record
# >www.ngolcbs.com 解析结果：Check no record
# >www.cnḃlogš.com 解析结果：Check no record
# >www.gcbolsn.com 解析结果：Check no record
# >www.bnlgosc.com 解析结果：Check no record
# >www.bnlsogc.com 解析结果：Check no record
# >www.cŋbloɢs.com 解析结果：Check no record
# >www.bnolscg.com 解析结果：Check no record
# >www.cnboslg.com 解析结果：Check no record
# >www.gcobnls.com 解析结果：Check no record
# >www.cñdlogs.com 解析结果：Check no record
# >www.nbosglc.com 解析结果：Check no record
# >www.cnḇlogş.com 解析结果：Check no record
# >www.solngbc.com 解析结果：Check no record
# >www.bogcnsl.com 解析结果：Check no record
# >www.clsongb.com 解析结果：Check no record
# >www.snogblc.com 解析结果：Check no record
# >www.sncoglb.com 解析结果：Check no record
# >www.nbslgco.com 解析结果：Check no record
# >www.lcbnosg.com 解析结果：Check no record
# >www.oscgbln.com 解析结果：Check no record
# >www.ongslcb.com 解析结果：Check no record
# >www.cgbslno.com 解析结果：Check no record
# >www.lcgnobs.com 解析结果：Check no record
# >www.bsclngo.com 解析结果：Check no record
# >www.obsgnlc.com 解析结果：Check no record
# >www.ongsclb.com 解析结果：Check no record
# >www.cńbloģs.com 解析结果：Check no record
# >www.cbgnslo.com 解析结果：Check no record
# >www.cnḇlogṣ.com 解析结果：Check no record
# >www.bnlscog.com 解析结果：Check no record
# >www.nlcsbog.com 解析结果：Check no record
# >www.olsgcnb.com 解析结果：Check no record
# >www.bsngolc.com 解析结果：Check no record
# >www.cgslonb.com 解析结果：Check no record
# >www.bsclgno.com 解析结果：Check no record
# >www.gocslnb.com 解析结果：Check no record
# >www.cñbĺogs.com 解析结果：Check no record
# >www.bgoscnl.com 解析结果：Check no record
# >www.gnosbcl.com 解析结果：Check no record
# >www.cgobnls.com 解析结果：Check no record
# >www.clnbsog.com 解析结果：Check no record
# >www.cobgnls.com 解析结果：Check no record
# >www.gbnolsc.com 解析结果：Check no record
# >www.soblgcn.com 解析结果：Check no record
# >www.onsglcb.com 解析结果：Check no record
# >www.cṉblogş.com 解析结果：Check no record
# >www.cǹbloǵs.com 解析结果：Check no record
# >www.sgclnob.com 解析结果：Check no record
# >www.lsgnobc.com 解析结果：Check no record
# >www.obgnslc.com 解析结果：Check no record
# >www.lbscgon.com 解析结果：Check no record
# >www.slbgonc.com 解析结果：Check no record
# >www.lobgcsn.com 解析结果：Check no record
# >www.gnoclbs.com 解析结果：Check no record
# >www.slogcbn.com 解析结果：Check no record
# >www.boslcng.com 解析结果：Check no record
# >www.cgblsno.com 解析结果：Check no record
# >www.ocgbnls.com 解析结果：Check no record
# >www.nobclsg.com 解析结果：Check no record
# >www.gclbons.com 解析结果：Check no record
# >www.lcgnosb.com 解析结果：Check no record
# >www.conlsbg.com 解析结果：Check no record
# >www.crbɫogs.com 解析结果：Check no record
# >www.lcbgnos.com 解析结果：Check no record
# >www.cnolsbg.com 解析结果：Check no record
# >www.locbngs.com 解析结果：Check no record
# >www.slbgcno.com 解析结果：Check no record
# >www.lbgsnoc.com 解析结果：Check no record
# >www.coblgns.com 解析结果：Check no record
# >www.gbolsnc.com 解析结果：Check no record
# >www.nsocblg.com 解析结果：Check no record
# >www.sblcngo.com 解析结果：Check no record
# >www.lgsncbo.com 解析结果：Check no record
# >www.cnbloxs.com 解析结果：Check no record
# >www.lsbnogc.com 解析结果：Check no record
# >www.obnscgl.com 解析结果：Check no record
# >www.nolcsgb.com 解析结果：Check no record
# >www.cgnoslb.com 解析结果：Check no record
# >www.lnsbogc.com 解析结果：Check no record
# >www.lsocbng.com 解析结果：Check no record
# >www.bsnlgco.com 解析结果：Check no record
# >www.cnolsgb.com 解析结果：Check no record
# >www.cnƅloǥs.com 解析结果：Check no record
# >www.cnosblg.com 解析结果：Check no record
# >www.scbognl.com 解析结果：Check no record
# >www.onlsbgc.com 解析结果：Check no record
# >www.gonsbcl.com 解析结果：Check no record
# >www.gonsblc.com 解析结果：Check no record
# >www.sgbnloc.com 解析结果：Check no record
# >www.sgclobn.com 解析结果：Check no record
# >www.cnlbgso.com 解析结果：Check no record
# >www.obslncg.com 解析结果：Check no record
# >www.socnbgl.com 解析结果：Check no record
# >www.lnsbcgo.com 解析结果：Check no record
# >www.logncsb.com 解析结果：Check no record
# >www.obclsgn.com 解析结果：Check no record
# >www.lngsocb.com 解析结果：Check no record
# >www.gcblnso.com 解析结果：Check no record
# >www.longcsb.com 解析结果：Check no record
# >www.bsnoclg.com 解析结果：Check no record
# >www.oglsbcn.com 解析结果：Check no record
# >www.nbclosg.com 解析结果：Check no record
# >www.lncosgb.com 解析结果：Check no record
# >www.scnglob.com 解析结果：Check no record
# >www.lgconbs.com 解析结果：Check no record
# >www.osbcgnl.com 解析结果：Check no record
# >www.slcbgno.com 解析结果：Check no record
# >www.ngblcso.com 解析结果：Check no record
# >www.glcsnob.com 解析结果：Check no record
# >www.bsngclo.com 解析结果：Check no record
# >www.bnscgol.com 解析结果：Check no record
# >www.gcnbslo.com 解析结果：Check no record
# >www.lscngbo.com 解析结果：Check no record
# >www.cndlogs.com 解析结果：Check no record
# >www.bclsgon.com 解析结果：Check no record
# >www.lsgoncb.com 解析结果：Check no record
# >www.cgnsobl.com 解析结果：Check no record
# >www.losgncb.com 解析结果：Check no record
# >www.lbsocgn.com 解析结果：Check no record
# >www.colsbng.com 解析结果：Check no record
# >www.cnlbosg.com 解析结果：Check no record
# >www.gnbcosl.com 解析结果：Check no record
# >www.ngoslbc.com 解析结果：Check no record
# >www.sbgnlco.com 解析结果：Check no record
# >www.sgcbnlo.com 解析结果：Check no record
# >www.gsconbl.com 解析结果：Check no record
# >www.bcnsglo.com 解析结果：Check no record
# >www.ocnlsbg.com 解析结果：Check no record
# >www.gnslboc.com 解析结果：Check no record
# >www.lcbosng.com 解析结果：Check no record
# >www.lbsgnoc.com 解析结果：Check no record
# >www.cǹbloɢs.com 解析结果：Check no record
# >www.gslbonc.com 解析结果：Check no record
# >www.cglsnob.com 解析结果：Check no record
# >www.boclngs.com 解析结果：Check no record
# >www.bgsclon.com 解析结果：Check no record
# >www.nogsblc.com 解析结果：Check no record
# >www.bscgonl.com 解析结果：Check no record
# >www.onsglbc.com 解析结果：Check no record
# >www.nobsglc.com 解析结果：Check no record
# >www.sgonbcl.com 解析结果：Check no record
# >www.sognbcl.com 解析结果：Check no record
# >www.ngsocbl.com 解析结果：Check no record
# >www.nolcbsg.com 解析结果：Check no record
# >www.nsgclob.com 解析结果：Check no record
# >www.slcbogn.com 解析结果：Check no record
# >www.cbolnsg.com 解析结果：Check no record
# >www.bnclogs.com 解析结果：Check no record
# >www.cgbslon.com 解析结果：Check no record
# >www.ogcslnb.com 解析结果：Check no record
# >www.lcgonsb.com 解析结果：Check no record
# >www.gsocbln.com 解析结果：Check no record
# >www.olngbsc.com 解析结果：Check no record
# >www.ogslnbc.com 解析结果：Check no record
# >www.lsogcnb.com 解析结果：Check no record
# >www.noblcgs.com 解析结果：Check no record
# >www.cobsnlg.com 解析结果：Check no record
# >www.bglocsn.com 解析结果：Check no record
# >www.cnbļoǥs.com 解析结果：Check no record
# >www.sobglnc.com 解析结果：Check no record
# >www.cnblsog.com 解析结果：Check no record
# >www.oclngbs.com 解析结果：Check no record
# >www.gbsnocl.com 解析结果：Check no record>www.lscbnog.com 解析结果：Check no record
#
# >www.cnbolsg.com 解析结果：Check no record
# >www.ncblosg.com 解析结果：Check no record
# >www.losncbg.com 解析结果：Check no record
# >www.cglosbn.com 解析结果：Check no record
# >www.snlbogc.com 解析结果：Check no record
# >www.cbsglno.com 解析结果：Check no record
# >www.osncbgl.com 解析结果：Check no record
# >www.nlgbsco.com 解析结果：Check no record
# >www.onlcsgb.com 解析结果：Check no record
# >www.lbsnogc.com 解析结果：Check no record
# >www.cnbłogş.com 解析结果：Check no record
# >www.cnḅiogs.com 解析结果：Check no record>www.sglocnb.com 解析结果：Check no record
#
# >www.bsgocnl.com 解析结果：Check no record
# >www.ogbcnsl.com 解析结果：Check no record
# >www.bolgsnc.com 解析结果：Check no record
# >www.bgslnco.com 解析结果：Check no record
# >www.lgcsbno.com 解析结果：Check no record
# >www.bogncls.com 解析结果：Check no record
# >www.bcsognl.com 解析结果：Check no record
# >www.clsnobg.com 解析结果：Check no record
# >www.nsglobc.com 解析结果：Check no record
# >www.ngclsob.com 解析结果：Check no record
# >www.nsoblgc.com 解析结果：Check no record
# >www.gnsolcb.com 解析结果：Check no record
# >www.obsclgn.com 解析结果：Check no record
# >www.blgncos.com 解析结果：Check no record
# >www.bngcsol.com 解析结果：Check no record
# >www.ngclsbo.com 解析结果：Check no record
# >www.nlgbocs.com 解析结果：Check no record
# >www.bcognsl.com 解析结果：Check no record
# >www.cngblos.com 解析结果：Check no record
# >www.scgnobl.com 解析结果：Check no record
# >www.nclsbog.com 解析结果：Check no record
# >www.golbnsc.com 解析结果：Check no record
# >www.olbcgns.com 解析结果：Check no record
# >www.cnlbgos.com 解析结果：Check no record
# >www.csgobnl.com 解析结果：Check no record
# >www.lgoncsb.com 解析结果：Check no record
# >www.cnblo3s.com 解析结果：Check no record
# >www.obgslnc.com 解析结果：Check no record
# >www.lsgbcon.com 解析结果：Check no record
# >www.slobgcn.com 解析结果：Check no record
# >www.snlbocg.com 解析结果：Check no record
# >www.csobgln.com 解析结果：Check no record
# >www.solgcnb.com 解析结果：Check no record
# >www.cblnsgo.com 解析结果：Check no record
# >www.osbcnlg.com 解析结果：Check no record
# >www.scblngo.com 解析结果：Check no record
# >www.obscnlg.com 解析结果：Check no record
# >www.cogblns.com 解析结果：Check no record
# >www.cgslobn.com 解析结果：Check no record
# >www.olgbcns.com 解析结果：Check no record
# >www.bslcgno.com 解析结果：Check no record
# >www.bolgcsn.com 解析结果：Check no record
# >www.bocsngl.com 解析结果：Check no record
# >www.bgolnsc.com 解析结果：Check no record
# >www.bgslcon.com 解析结果：Check no record
# >www.glbncos.com 解析结果：Check no record
# >www.osglcnb.com 解析结果：Check no record
# >www.cgoslbn.com 解析结果：Check no record
# >www.bsonlgc.com 解析结果：Check no record
# >www.cņbiogs.com 解析结果：Check no record
# >www.bncolsg.com 解析结果：Check no record
# >www.clbnsgo.com 解析结果：Check no record
# >www.cņblogş.com 解析结果：Check no record
# >www.obsglnc.com 解析结果：Check no record
# >www.csglobn.com 解析结果：Check no record
# >www.ncbogsl.com 解析结果：Check no record
# >www.olbscng.com 解析结果：Check no record
# >www.cnbloɡs.com 解析结果：Check no record
# >www.ngcsblo.com 解析结果：Check no record
# >www.cṅbiogs.com 解析结果：Check no record
# >www.blsongc.com 解析结果：Check no record
# >www.csonblg.com 解析结果：Check no record
# >www.oblcnsg.com 解析结果：Check no record
# >www.sbgolnc.com 解析结果：Check no record
# >www.cblogsn.com 解析结果：Check no record
# >www.lgnscbo.com 解析结果：Check no record
# >www.blsngoc.com 解析结果：Check no record
# >www.glbosnc.com 解析结果：Check no record
# >www.gbsnlco.com 解析结果：Check no record
# >www.obglscn.com 解析结果：Check no record
# >www.sglbnoc.com 解析结果：Check no record
# >www.cjblogs.com 解析结果：3.140.13.188,18.119.154.66
# >www.nocbgls.com 解析结果：Check no record
# >www.gcnsblo.com 解析结果：Check no record
# >www.cṇbloɡs.com 解析结果：Check no record
# >www.cnḇľogs.com 解析结果：Check no record
# >www.cnḇloğs.com 解析结果：Check no record
# >www.bosnlgc.com 解析结果：Check no record
# >www.gsbonlc.com 解析结果：Check no record
# >www.nlcgobs.com 解析结果：Check no record
# >www.ogblsnc.com 解析结果：Check no record
# >www.bgsclno.com 解析结果：Check no record
# >www.sgconlb.com 解析结果：Check no record
# >www.gsboncl.com 解析结果：Check no record
# >www.obnclgs.com 解析结果：Check no record
# >www.csnbolg.com 解析结果：Check no record
# >www.scgnbol.com 解析结果：Check no record
# >www.lnbgcos.com 解析结果：Check no record
# >www.sbcgnlo.com 解析结果：Check no record
# >www.nboglcs.com 解析结果：Check no record
# >www.locnbgs.com 解析结果：Check no record
# >www.olngbcs.com 解析结果：Check no record
# >www.ngcbosl.com 解析结果：Check no record
# >www.cṉbloġs.com 解析结果：Check no record
# >www.cnḃłogs.com 解析结果：Check no record
# >www.nlscgob.com 解析结果：Check no record
# >www.osnlcgb.com 解析结果：Check no record
# >www.cṉɓlogs.com 解析结果：Check no record
# >www.scogbnl.com 解析结果：Check no record
# >www.slocngb.com 解析结果：Check no record
# >www.nsblgco.com 解析结果：Check no record
# >www.lgboncs.com 解析结果：Check no record
# >www.olcgbsn.com 解析结果：Check no record
# >www.bscnlgo.com 解析结果：Check no record
# >www.gslcnob.com 解析结果：Check no record
# >www.nlbcsog.com 解析结果：Check no record
# >www.cŋbɫogs.com 解析结果：Check no record
# >www.solbncg.com 解析结果：Check no record
# >www.lsogcbn.com 解析结果：Check no record
# >www.lgbnosc.com 解析结果：Check no record
# >www.bolcnsg.com 解析结果：Check no record
# >www.cbgosln.com 解析结果：Check no record
# >www.nobgcls.com 解析结果：Check no record
# >www.bcosngl.com 解析结果：Check no record
# >www.ncolbgs.com 解析结果：Check no record
# >www.slgnbco.com 解析结果：Check no record
# >www.gsnclbo.com 解析结果：Check no record
# >www.clsobng.com 解析结果：Check no record
# >www.nlbgsoc.com 解析结果：Check no record
# >www.ncolbsg.com 解析结果：Check no record
# >www.cnblo2s.com 解析结果：Check no record
# >www.gcbolns.com 解析结果：Check no record
# >www.cnsblgo.com 解析结果：Check no record
# >www.sgnobcl.com 解析结果：Check no record
# >www.blgocns.com 解析结果：Check no record
# >www.sblgcon.com 解析结果：Check no record
# >www.glosbcn.com 解析结果：Check no record
# >www.solnbcg.com 解析结果：Check no record
# >www.sbngclo.com 解析结果：Check no record
# >www.cglnosb.com 解析结果：Check no record
# >www.olsbngc.com 解析结果：Check no record
# >www.gsbnclo.com 解析结果：Check no record
# >www.glsnocb.com 解析结果：Check no record
# >www.bncgosl.com 解析结果：Check no record
# >www.nbsolcg.com 解析结果：Check no record
# >www.cnḃĺogs.com 解析结果：Check no record
# >www.bloscng.com 解析结果：Check no record
# >www.cṉbloǧs.com 解析结果：Check no record
# >www.cbolsng.com 解析结果：Check no record
# >www.gcbosln.com 解析结果：Check no record
# >www.olgnbcs.com 解析结果：Check no record
# >www.bgnlsoc.com 解析结果：Check no record
# >www.cńblogś.com 解析结果：Check no record
# >www.oslbcgn.com 解析结果：Check no record
# >www.cṉbłogs.com 解析结果：Check no record
# >www.oslcgbn.com 解析结果：Check no record
# >www.glsbcon.com 解析结果：Check no record
# >www.csgonbl.com 解析结果：Check no record
# >www.nsglboc.com 解析结果：Check no record
# >www.bosncgl.com 解析结果：Check no record
#
# DNS查询过滤域名个数：1000->5
#      fuzzer           domain  score  \
# 0  addition  www.cnhlogs.com    0.0
# 1  addition  www.sblngco.com    0.0
# 2  addition  www.cnblogs.com    0.0
# 3  addition  www.ncsblog.com    0.0
# 4  addition  www.cjblogs.com    0.0
#
#                                      dns_record
# 0  198.54.117.217,198.54.117.212,198.54.117.210
# 1                                34.102.136.180
# 2   114.55.187.58,101.37.115.180,114.55.205.139
# 3                  34.205.242.146,54.161.222.85
# 4                    3.140.13.188,18.119.154.66

# %%
pd.DataFrame(domains)
# Out:
#      fuzzer           domain  score  \
# 0  addition  www.cnhlogs.com    0.0
# 1  addition  www.sblngco.com    0.0
# 2  addition  www.cnblogs.com    0.0
# 3  addition  www.ncsblog.com    0.0
# 4  addition  www.cjblogs.com    0.0
#
#                                      dns_record
# 0  198.54.117.217,198.54.117.212,198.54.117.210
# 1                                34.102.136.180
# 2   114.55.187.58,101.37.115.180,114.55.205.139
# 3                  34.205.242.146,54.161.222.85
# 4                    3.140.13.188,18.119.154.66

# %%
save_domains(domains, "{}DNS过滤后的混淆域名".format(url.domain))
# Out:
# 文件：D:\Desktop\上班\dnstwist-20230509\Similar_domain_name_detection\www.cnblogs.comDNS过滤后的混淆域名.csv保存成功

# %%
domains = LSH_alg(args['domain'], domains, args['request_timeout_http'], args['useragent'], args['option_lsh'])
# Out:
# 将要进行LSH检测的域名：
#
#      fuzzer           domain  score  \
# 0  addition  www.cnhlogs.com    0.0
# 1  addition  www.sblngco.com    0.0
# 2  addition  www.cnblogs.com    0.0
# 3  addition  www.ncsblog.com    0.0
# 4  addition  www.cjblogs.com    0.0
#
#                                      dns_record
# 0  198.54.117.217,198.54.117.212,198.54.117.210
# 1                                34.102.136.180
# 2   114.55.187.58,101.37.115.180,114.55.205.139
# 3                  34.205.242.146,54.161.222.85
# 4                    3.140.13.188,18.119.154.66
# >www.sblngco.com的LSH得分：0
# >www.cnblogs.com的LSH得分：100
# >www.cnhlogs.com的LSH得分：0
# >www.ncsblog.com的LSH得分：0
# >www.cjblogs.com的LSH得分：0

# %%
pd.DataFrame(domains)
# Out:
#      fuzzer           domain  score  \
# 0  addition  www.sblngco.com    0.0
# 1  addition  www.cnblogs.com    0.0
# 2  addition  www.cnhlogs.com    0.0
# 3  addition  www.ncsblog.com    0.0
# 4  addition  www.cjblogs.com    0.0
#
#                                      dns_record  LSH_score
# 0                                34.102.136.180          0
# 1   114.55.187.58,101.37.115.180,114.55.205.139        100
# 2  198.54.117.217,198.54.117.212,198.54.117.210          0
# 3                  34.205.242.146,54.161.222.85          0
# 4                    3.140.13.188,18.119.154.66          0

# %%
save_domains(domains, "{}LSH过滤后的混淆域名".format(url.domain))
# Out:
# 文件：D:\Desktop\上班\dnstwist-20230509\Similar_domain_name_detection\www.cnblogs.comLSH过滤后的混淆域名.csv保存成功
